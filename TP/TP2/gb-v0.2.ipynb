# %% [markdown]
# <h1 style="text-align: center;" markdown="1">TP2: Gradient Boost con tuneo de parametros</h1>
# ![](../data/icon_properati-data.png)

# %%
import numpy as np 
import pandas as pd

# plots
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %pylab inline

# modules
import knn as knnlibrary
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/conda/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
properties =knnlibrary.get_dataset()
properties.describe()
# Out:
# /opt/conda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#         geonames_id            lat            lon         price  \
# count  3.099760e+05  311335.000000  311335.000000  3.335230e+05
# mean   3.563875e+06     -34.633643     -59.313466  3.967361e+05
# std    3.919931e+05       2.141045       2.449846  1.436736e+06
# min    3.427208e+06     -54.833014    -122.419415  0.000000e+00
# 25%             NaN            NaN            NaN           NaN
# 50%             NaN            NaN            NaN           NaN
# 75%             NaN            NaN            NaN           NaN
# max    6.948895e+06      37.774929       3.379206  6.500000e+08
#
#        price_aprox_local_currency  price_aprox_usd  surface_total_in_m2  \
# count                3.335230e+05     3.335230e+05        260093.000000
# mean                 4.062802e+06     2.420167e+05           292.756133
# std                  7.128929e+06     4.189991e+05          2164.556274
# min                  0.000000e+00     0.000000e+00             0.000000
# 25%                           NaN              NaN                  NaN
# 50%                           NaN              NaN                  NaN
# 75%                           NaN              NaN                  NaN
# max                  8.194558e+08     5.000000e+07        200000.000000
#
#        surface_covered_in_m2  price_usd_per_m2  price_per_m2         floor  \
# count           3.075060e+05      2.186000e+05  2.728530e+05  36414.000000
# mean            6.651399e+03      1.918414e+03  5.521272e+03     14.933734
# std             3.606644e+06      3.893250e+03  2.520627e+04    184.897796
# min            -7.000000e+01      0.000000e+00  5.000000e-05      1.000000
# 25%                      NaN               NaN           NaN           NaN
# 50%                      NaN               NaN           NaN           NaN
# 75%                      NaN               NaN           NaN           NaN
# max             2.000000e+09      1.271027e+06  4.000000e+06  27201.000000
#
#                rooms      expenses
# count  229854.000000  3.592400e+04
# mean        3.093977  4.898150e+03
# std         1.700742  1.089441e+05
# min         1.000000  1.000000e+00
# 25%              NaN           NaN
# 50%              NaN           NaN
# 75%              NaN           NaN
# max        40.000000  1.000150e+07

# %%
# filtro por CABA y GBA
properties_caba = properties[(properties['place_with_parent_names'].str.contains('Capital Federal') \
                             | properties['place_with_parent_names'].str.contains('Bs.As. G.B.A.'))]

properties_caba = properties_caba[properties_caba['price'].notnull() & properties_caba['price'] > 0 & properties_caba['place_name'].notnull()]

# eliminamos propiedades con mas de 54 pisos
properties_caba = properties_caba[properties_caba['floor'] <= 60]
# eliminamos propiedades con mas de 9 pisos - ver analisis
properties_caba = properties_caba[properties_caba['rooms'] <=  10]
# eliminamos propiedades con mas de 2000 m2 de superficie cubierta - ver analisis
properties_caba = properties_caba[(properties_caba['surface_covered_in_m2'] <= 4000) & (properties_caba['surface_covered_in_m2'] >= 0)]
# eliminamos propiedades con mas de 2000 m2 de superficie cubierta - ver analisis
properties_caba = properties_caba[(properties_caba['surface_total_in_m2']<= 6000)  & (properties_caba['surface_total_in_m2'] >= 0)]
properties_caba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9204 entries, 16 to 34504
# Data columns (total 27 columns):
# id                            9204 non-null object
# created_on                    9204 non-null object
# operation                     9204 non-null object
# property_type                 9204 non-null object
# place_name                    9204 non-null object
# place_with_parent_names       9204 non-null object
# country_name                  9204 non-null object
# state_name                    9204 non-null object
# geonames_id                   8045 non-null float64
# lat-lon                       8500 non-null object
# lat                           8500 non-null float64
# lon                           8500 non-null float64
# price                         9204 non-null float64
# currency                      9204 non-null object
# price_aprox_local_currency    9204 non-null float64
# price_aprox_usd               9204 non-null float64
# surface_total_in_m2           9204 non-null float64
# surface_covered_in_m2         9204 non-null float64
# price_usd_per_m2              9204 non-null float64
# price_per_m2                  9204 non-null float64
# floor                         9204 non-null float64
# rooms                         9204 non-null float64
# expenses                      3672 non-null float64
# properati_url                 9204 non-null object
# description                   9204 non-null object
# title                         9204 non-null object
# image_thumbnail               9200 non-null object
# dtypes: float64(13), object(14)
# memory usage: 2.0+ MB

# %%
# filtro columnas segun lo que hay en el dataset
attributes = ['created_on','property_type','place_name','place_with_parent_names',\
              'country_name','state_name','lat','lon','surface_total_in_m2','surface_covered_in_m2',\
              'floor','rooms', 'price']
properties_caba[attributes].info()
properties_caba_with_price_attributes = properties_caba[attributes]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9204 entries, 16 to 34504
# Data columns (total 13 columns):
# created_on                 9204 non-null object
# property_type              9204 non-null object
# place_name                 9204 non-null object
# place_with_parent_names    9204 non-null object
# country_name               9204 non-null object
# state_name                 9204 non-null object
# lat                        8500 non-null float64
# lon                        8500 non-null float64
# surface_total_in_m2        9204 non-null float64
# surface_covered_in_m2      9204 non-null float64
# floor                      9204 non-null float64
# rooms                      9204 non-null float64
# price                      9204 non-null float64
# dtypes: float64(7), object(6)
# memory usage: 1006.7+ KB

# %%
from sklearn.preprocessing import LabelEncoder

properties_caba_with_price_attributes.fillna('NaN', inplace=True)
# atributos categoricos
encoder = LabelEncoder()

properties_caba_with_price_attributes['property_type'] = encoder.fit_transform(properties_caba_with_price_attributes[['property_type']])
#properties_caba_with_price_attributes['operation'] = encoder.fit_transform(properties_caba_with_price_attributes[['operation']])
properties_caba_with_price_attributes['place_name'] = encoder.fit_transform(properties_caba_with_price_attributes[['place_name']])
properties_caba_with_price_attributes['place_with_parent_names'] = encoder.fit_transform(properties_caba_with_price_attributes[['place_with_parent_names']])
properties_caba_with_price_attributes['country_name'] = encoder.fit_transform(properties_caba_with_price_attributes[['country_name']])
properties_caba_with_price_attributes['state_name'] = encoder.fit_transform(properties_caba_with_price_attributes[['state_name']])
properties_caba_with_price_attributes['created_on'] = encoder.fit_transform(properties_caba_with_price_attributes[['created_on']])
# completamos valores nan
from sklearn.preprocessing import Imputer
imputer_mean = Imputer(missing_values='NaN', strategy='mean', axis=0)
properties_caba_with_price_attributes["lat"] = imputer_mean.fit_transform(properties_caba_with_price_attributes[["lat"]])
properties_caba_with_price_attributes["lon"] = imputer_mean.fit_transform(properties_caba_with_price_attributes[["lon"]])

properties_caba_with_price_attributes.head()
# Out:
# /opt/conda/lib/python3.5/site-packages/pandas/core/frame.py:2762: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
# /opt/conda/lib/python3.5/site-packages/sklearn/preprocessing/label.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     created_on  property_type  place_name  place_with_parent_names  \
# 16         133              1         129                       69
# 17         133              1         129                       69
# 18         133              1         129                       69
# 19         133              1         129                       69
# 20         133              1         129                       69
#
#     country_name  state_name        lat        lon  surface_total_in_m2  \
# 16             0           1 -34.680247 -58.553347                 59.0
# 17             0           1 -34.680247 -58.553347                 59.0
# 18             0           1 -34.680247 -58.553347                 59.0
# 19             0           1 -34.680247 -58.553347                 59.0
# 20             0           1 -34.680247 -58.553347                 55.0
#
#     surface_covered_in_m2  floor  rooms    price
# 16                   55.0    1.0    2.0  93000.0
# 17                   55.0    2.0    2.0  93000.0
# 18                   55.0    3.0    2.0  93000.0
# 19                   55.0    4.0    2.0  93000.0
# 20                   55.0    1.0    2.0  93000.0

# %%
# separamos el set de train
from sklearn.model_selection import train_test_split
import datetime

now = datetime.datetime.now()

# separamos el train de traing para validarlo luego usando un 30% de los datos
X, y = properties_caba_with_price_attributes.iloc[:, properties_caba_with_price_attributes.columns != 'price'].values, properties_caba_with_price_attributes.iloc[:, properties_caba_with_price_attributes.columns == 'price'].values
X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=0.2, random_state=200)
    
print(y_train)
    
len(X_test), len(X_train)
# Out:
# [[  159500.]
#  [ 1598387.]
#  [  127000.]
#  ...,
#  [   70000.]
#  [  170000.]
#  [  340000.]]
# (1841, 7363)

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor

#Choose all predictors except target & IDcols
param_test1 = {'n_estimators': [1500,1700,2000]}
gbr = GradientBoostingRegressor(learning_rate=0.1, min_samples_split=500,min_samples_leaf=50,max_depth=8,
                          max_features='sqrt',subsample=0.8,random_state=10)

gsearch1 = GridSearchCV(estimator=gbr, param_grid = param_test1,iid=False, cv=10)
gsearch1.fit(X_train,y_train.ravel())

gsearch1.grid_scores_, gsearch1.best_params_, gsearch1.best_score_
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=8,
#              max_features='sqrt', max_leaf_nodes=None,
#              min_impurity_decrease=0.0, min_impurity_split=None,
#              min_samples_leaf=50, min_samples_split=500,
#              min_weight_fraction_leaf=0.0, n_estimators=100,
#              presort='auto', random_state=10, subsample=0.8, verbose=0,
#              warm_start=False),
#        fit_params={}, iid=False, n_jobs=1,
#        param_grid={'n_estimators': [1500, 1700, 2000]},
#        pre_dispatch='2*n_jobs', refit=True, scoring=None, verbose=0)

# %%
# test max_depth and min_samples_split
param_test2 = {'max_depth':[5,7,9,11,13,15,17,19,21], 'min_samples_split':[200,400,600,800,1000,1200]}
gbr = GradientBoostingRegressor(learning_rate=0.1, n_estimators=100, max_features='sqrt', subsample=0.8, random_state=10)

gsearch2 = GridSearchCV(estimator=gbr,param_grid = param_test2, iid=False, cv=10)

gsearch2.fit(X_train,y_train.ravel())

gsearch2.grid_scores_, gsearch2.best_params_, gsearch2.best_score_
# Out:
# ([mean: 0.47358, std: 0.10193, params: {'max_depth': 5, 'min_samples_split': 200},
#   mean: 0.44756, std: 0.11698, params: {'max_depth': 5, 'min_samples_split': 400},
#   mean: 0.43903, std: 0.10768, params: {'max_depth': 5, 'min_samples_split': 600},
#   mean: 0.40989, std: 0.11877, params: {'max_depth': 5, 'min_samples_split': 800},
#   mean: 0.40800, std: 0.11218, params: {'max_depth': 5, 'min_samples_split': 1000},
#   mean: 0.39541, std: 0.10665, params: {'max_depth': 5, 'min_samples_split': 1200},
#   mean: 0.51849, std: 0.11003, params: {'max_depth': 7, 'min_samples_split': 200},
#   mean: 0.46417, std: 0.13450, params: {'max_depth': 7, 'min_samples_split': 400},
#   mean: 0.46199, std: 0.11817, params: {'max_depth': 7, 'min_samples_split': 600},
#   mean: 0.44651, std: 0.11947, params: {'max_depth': 7, 'min_samples_split': 800},
#   mean: 0.43055, std: 0.11933, params: {'max_depth': 7, 'min_samples_split': 1000},
#   mean: 0.42794, std: 0.11503, params: {'max_depth': 7, 'min_samples_split': 1200},
#   mean: 0.56725, std: 0.12017, params: {'max_depth': 9, 'min_samples_split': 200},
#   mean: 0.49817, std: 0.11888, params: {'max_depth': 9, 'min_samples_split': 400},
#   mean: 0.48184, std: 0.12416, params: {'max_depth': 9, 'min_samples_split': 600},
#   mean: 0.48256, std: 0.11388, params: {'max_depth': 9, 'min_samples_split': 800},
#   mean: 0.45238, std: 0.12257, params: {'max_depth': 9, 'min_samples_split': 1000},
#   mean: 0.44033, std: 0.12401, params: {'max_depth': 9, 'min_samples_split': 1200},
#   mean: 0.58012, std: 0.12908, params: {'max_depth': 11, 'min_samples_split': 200},
#   mean: 0.54011, std: 0.10993, params: {'max_depth': 11, 'min_samples_split': 400},
#   mean: 0.50002, std: 0.13468, params: {'max_depth': 11, 'min_samples_split': 600},
#   mean: 0.48669, std: 0.11913, params: {'max_depth': 11, 'min_samples_split': 800},
#   mean: 0.46623, std: 0.11806, params: {'max_depth': 11, 'min_samples_split': 1000},
#   mean: 0.45230, std: 0.13016, params: {'max_depth': 11, 'min_samples_split': 1200},
#   mean: 0.58416, std: 0.12143, params: {'max_depth': 13, 'min_samples_split': 200},
#   mean: 0.54379, std: 0.11849, params: {'max_depth': 13, 'min_samples_split': 400},
#   mean: 0.51299, std: 0.13503, params: {'max_depth': 13, 'min_samples_split': 600},
#   mean: 0.48920, std: 0.13154, params: {'max_depth': 13, 'min_samples_split': 800},
#   mean: 0.47748, std: 0.11688, params: {'max_depth': 13, 'min_samples_split': 1000},
#   mean: 0.45812, std: 0.12592, params: {'max_depth': 13, 'min_samples_split': 1200},
#   mean: 0.59939, std: 0.13114, params: {'max_depth': 15, 'min_samples_split': 200},
#   mean: 0.55828, std: 0.11381, params: {'max_depth': 15, 'min_samples_split': 400},
#   mean: 0.51459, std: 0.13475, params: {'max_depth': 15, 'min_samples_split': 600},
#   mean: 0.48831, std: 0.13084, params: {'max_depth': 15, 'min_samples_split': 800},
#   mean: 0.46947, std: 0.12284, params: {'max_depth': 15, 'min_samples_split': 1000},
#   mean: 0.45843, std: 0.13445, params: {'max_depth': 15, 'min_samples_split': 1200},
#   mean: 0.59228, std: 0.13947, params: {'max_depth': 17, 'min_samples_split': 200},
#   mean: 0.54359, std: 0.13995, params: {'max_depth': 17, 'min_samples_split': 400},
#   mean: 0.53778, std: 0.12309, params: {'max_depth': 17, 'min_samples_split': 600},
#   mean: 0.49960, std: 0.13166, params: {'max_depth': 17, 'min_samples_split': 800},
#   mean: 0.48187, std: 0.12675, params: {'max_depth': 17, 'min_samples_split': 1000},
#   mean: 0.46045, std: 0.12795, params: {'max_depth': 17, 'min_samples_split': 1200},
#   mean: 0.61445, std: 0.13438, params: {'max_depth': 19, 'min_samples_split': 200},
#   mean: 0.54035, std: 0.14078, params: {'max_depth': 19, 'min_samples_split': 400},
#   mean: 0.52263, std: 0.13571, params: {'max_depth': 19, 'min_samples_split': 600},
#   mean: 0.50034, std: 0.13707, params: {'max_depth': 19, 'min_samples_split': 800},
#   mean: 0.48649, std: 0.12736, params: {'max_depth': 19, 'min_samples_split': 1000},
#   mean: 0.45350, std: 0.13443, params: {'max_depth': 19, 'min_samples_split': 1200},
#   mean: 0.59700, std: 0.12830, params: {'max_depth': 21, 'min_samples_split': 200},
#   mean: 0.55200, std: 0.12600, params: {'max_depth': 21, 'min_samples_split': 400},
#   mean: 0.52058, std: 0.12943, params: {'max_depth': 21, 'min_samples_split': 600},
#   mean: 0.49674, std: 0.13349, params: {'max_depth': 21, 'min_samples_split': 800},
#   mean: 0.47636, std: 0.13395, params: {'max_depth': 21, 'min_samples_split': 1000},
#   mean: 0.46081, std: 0.12723, params: {'max_depth': 21, 'min_samples_split': 1200}],
#  {'max_depth': 19, 'min_samples_split': 200},
#  0.61444960275183)

# %%
# test min_samples_spliy and min_samples_leaf
param_test3 = {'min_samples_split':[200,400,600,800,1000], 'min_samples_leaf':[100,200,400,600,800]}
gbr = GradientBoostingRegressor(max_depth=19, learning_rate=0.1, n_estimators=100, max_features='sqrt', 
                                subsample=0.8, random_state=10)

gsearch3 = GridSearchCV(estimator=gbr, param_grid=param_test3, iid=False, cv=10)
gsearch3.fit(X_train,y_train.ravel())

gsearch3.grid_scores_, gsearch3.best_params_, gsearch3.best_score_
# no set min_samples_leaf
# Out:
# ([mean: 0.48490, std: 0.14134, params: {'min_samples_leaf': 100, 'min_samples_split': 200},
#   mean: 0.45322, std: 0.14144, params: {'min_samples_leaf': 100, 'min_samples_split': 400},
#   mean: 0.43336, std: 0.13919, params: {'min_samples_leaf': 100, 'min_samples_split': 600},
#   mean: 0.41598, std: 0.13078, params: {'min_samples_leaf': 100, 'min_samples_split': 800},
#   mean: 0.39818, std: 0.12817, params: {'min_samples_leaf': 100, 'min_samples_split': 1000},
#   mean: 0.40802, std: 0.12935, params: {'min_samples_leaf': 200, 'min_samples_split': 200},
#   mean: 0.40802, std: 0.12935, params: {'min_samples_leaf': 200, 'min_samples_split': 400},
#   mean: 0.38509, std: 0.12168, params: {'min_samples_leaf': 200, 'min_samples_split': 600},
#   mean: 0.37010, std: 0.11716, params: {'min_samples_leaf': 200, 'min_samples_split': 800},
#   mean: 0.35248, std: 0.11404, params: {'min_samples_leaf': 200, 'min_samples_split': 1000},
#   mean: 0.31129, std: 0.09300, params: {'min_samples_leaf': 400, 'min_samples_split': 200},
#   mean: 0.31129, std: 0.09300, params: {'min_samples_leaf': 400, 'min_samples_split': 400},
#   mean: 0.31129, std: 0.09300, params: {'min_samples_leaf': 400, 'min_samples_split': 600},
#   mean: 0.31129, std: 0.09300, params: {'min_samples_leaf': 400, 'min_samples_split': 800},
#   mean: 0.30337, std: 0.09187, params: {'min_samples_leaf': 400, 'min_samples_split': 1000},
#   mean: 0.25152, std: 0.07471, params: {'min_samples_leaf': 600, 'min_samples_split': 200},
#   mean: 0.25152, std: 0.07471, params: {'min_samples_leaf': 600, 'min_samples_split': 400},
#   mean: 0.25152, std: 0.07471, params: {'min_samples_leaf': 600, 'min_samples_split': 600},
#   mean: 0.25152, std: 0.07471, params: {'min_samples_leaf': 600, 'min_samples_split': 800},
#   mean: 0.25152, std: 0.07471, params: {'min_samples_leaf': 600, 'min_samples_split': 1000},
#   mean: 0.20659, std: 0.05520, params: {'min_samples_leaf': 800, 'min_samples_split': 200},
#   mean: 0.20659, std: 0.05520, params: {'min_samples_leaf': 800, 'min_samples_split': 400},
#   mean: 0.20659, std: 0.05520, params: {'min_samples_leaf': 800, 'min_samples_split': 600},
#   mean: 0.20659, std: 0.05520, params: {'min_samples_leaf': 800, 'min_samples_split': 800},
#   mean: 0.20659, std: 0.05520, params: {'min_samples_leaf': 800, 'min_samples_split': 1000}],
#  {'min_samples_leaf': 100, 'min_samples_split': 200},
#  0.48490489443930124)

# %%
# test max_features
param_test4 = {'max_features':[2,4,7]}
gbr = GradientBoostingRegressor(max_depth=19, learning_rate=0.1, n_estimators=100, max_features='sqrt', 
                                subsample=0.8, random_state=10)

gsearch4 = GridSearchCV(estimator=gbr, param_grid=param_test4, iid=False, cv=10)
gsearch4.fit(X_train,y_train.ravel())

gsearch4.grid_scores_, gsearch4.best_params_, gsearch4.best_score_
# Out:
# ([mean: 0.62508, std: 0.17030, params: {'max_features': 2},
#   mean: 0.62351, std: 0.15638, params: {'max_features': 4},
#   mean: 0.60953, std: 0.15808, params: {'max_features': 7}],
#  {'max_features': 2},
#  0.6250839087604364)

# %%
# test subsample
param_test5 = {'subsample':[0.6,0.7,0.75,0.8,0.85,0.9]}
gbr = GradientBoostingRegressor(max_depth=19, learning_rate=0.1, n_estimators=100, max_features=2, 
                                subsample=0.8, random_state=10)

gsearch5 = GridSearchCV(estimator=gbr, param_grid=param_test5, iid=False, cv=10)
gsearch5.fit(X_train,y_train.ravel())

gsearch5.grid_scores_, gsearch5.best_params_, gsearch5.best_score_
# Out:
# ([mean: 0.61710, std: 0.15904, params: {'subsample': 0.6},
#   mean: 0.61820, std: 0.16454, params: {'subsample': 0.7},
#   mean: 0.62237, std: 0.14630, params: {'subsample': 0.75},
#   mean: 0.62508, std: 0.17030, params: {'subsample': 0.8},
#   mean: 0.62889, std: 0.13596, params: {'subsample': 0.85},
#   mean: 0.64805, std: 0.15906, params: {'subsample': 0.9}],
#  {'subsample': 0.9},
#  0.6480546142026282)

# %% [markdown]
# ## Aumentando los estimadores y disminuyendo el learning rate

# %%
from sklearn.metrics import r2_score, mean_squared_error

gbr = GradientBoostingRegressor(max_depth=19, learning_rate=0.1, n_estimators=400, max_features=2, 
                                subsample=0.9, random_state=10)

gbr.fit(X_train,y_train.ravel())
r2_score(y_test.ravel(), gbr.predict(X_test))
# Out:
# 0.65838001110252409

# %% [markdown]
# # TEST

# %%
# leemos set de test
test_df = pd.read_csv('../data/test/properati_dataset_testing_noprice.csv', low_memory=False)
test_df.head()
# Out:
#         id  created_on property_type operation             place_name  \
# 0     3632  2017-08-24  departamento     venta          Puerto Madero
# 1     3633  2017-08-25  departamento     venta  Buenos Aires Interior
# 2  2263404  2017-08-01  departamento     venta           Palermo Soho
# 3  2263405  2017-08-01  departamento     venta              Chacarita
# 4  2263406  2017-08-01  departamento     venta              Chacarita
#
#                             place_with_parent_names country_name  \
# 0         |Argentina|Capital Federal|Puerto Madero|    Argentina
# 1                 |Argentina|Buenos Aires Interior|    Argentina
# 2  |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 3             |Argentina|Capital Federal|Chacarita|    Argentina
# 4             |Argentina|Capital Federal|Chacarita|    Argentina
#
#               state_name                        lat-lon        lat        lon  \
# 0        Capital Federal  -34.6109877599,-58.3634635778 -34.610988 -58.363464
# 1  Buenos Aires Interior                            NaN        NaN        NaN
# 2        Capital Federal  -34.5893633232,-58.4128798588 -34.589363 -58.412880
# 3        Capital Federal                            NaN        NaN        NaN
# 4        Capital Federal                            NaN        NaN        NaN
#
#    surface_total_in_m2  surface_covered_in_m2  floor  rooms expenses  \
# 0                  0.0                    NaN    NaN    NaN      NaN
# 1                  0.0                    NaN    NaN    NaN      NaN
# 2                 53.0                   48.0    NaN    NaN     1500
# 3                 39.0                   39.0    NaN    NaN      NaN
# 4                 51.0                   51.0    NaN    NaN      NaN
#
#                                          description
# 0  Edificio BA Houses situado frente al Dique 3 d...
# 1  El departamento cuenta con un living-comedor a...
# 2                  IMPECABLE TORRE COY III – DEPA...
# 3                  AMBIENTE DIVISIBLE CON PISOS D...
# 4                  LIVING COMEDOR CON PISOS DE PO...

# %%
# transformamos atributos categoricos
test_df['place_name'] = encoder.fit_transform(test_df[['place_name']])
test_df['state_name'] = encoder.fit_transform(test_df[['state_name']])
test_df['place_with_parent_names'] = encoder.fit_transform(test_df[['place_with_parent_names']])
test_df['property_type'] = encoder.fit_transform(test_df[['property_type']])
test_df['created_on'] = encoder.fit_transform(test_df[['created_on']])
test_df['country_name'] = encoder.fit_transform(test_df[['country_name']])

X_test_df = test_df[['created_on','property_type','place_name','place_with_parent_names',\
              'country_name','state_name','lat','lon','surface_total_in_m2','surface_covered_in_m2',\
              'floor','rooms']]

# completamos valores nan
from sklearn.preprocessing import Imputer
imputer_mean = Imputer(missing_values='NaN', strategy='mean', axis=0)
X_test_df['floor'] = X_test_df[['floor']].fillna(1)
X_test_df['rooms'] = X_test_df[['rooms']].fillna(1)

X_test_df["surface_total_in_m2"] = imputer_mean.fit_transform(X_test_df[["surface_total_in_m2"]])
X_test_df["surface_covered_in_m2"] = imputer_mean.fit_transform(X_test_df[["surface_covered_in_m2"]])
X_test_df["lat"] = imputer_mean.fit_transform(X_test_df[["lat"]])
X_test_df["lon"] = imputer_mean.fit_transform(X_test_df[["lon"]])

X_test_df.info()
# Out:
# /opt/conda/lib/python3.5/site-packages/sklearn/preprocessing/label.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14166 entries, 0 to 14165
# Data columns (total 12 columns):
# created_on                 14166 non-null int64
# property_type              14166 non-null int64
# place_name                 14166 non-null int64
# place_with_parent_names    14166 non-null int64
# country_name               14166 non-null int64
# state_name                 14166 non-null int64
# lat                        14166 non-null float64
# lon                        14166 non-null float64
# surface_total_in_m2        14166 non-null float64
# surface_covered_in_m2      14166 non-null float64
# floor                      14166 non-null float64
# rooms                      14166 non-null float64
# dtypes: float64(6), int64(6)
# memory usage: 1.3 MB

# %%
# prediccion del set de test
#knn = KNeighborsRegressor(n_neighbors=best_k, weights='distance', p=best_p)
#knn.fit(X_train_std[:, k_param], y_train)
X_test_df['prediction'] = gbr.predict(X_test_df)
X_test_df.head(10)
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    created_on  property_type  place_name  place_with_parent_names  \
# 0          23              1         152                      219
# 1          24              1          29                      180
# 2           0              1         136                      210
# 3           0              1          40                      193
# 4           0              1          40                      193
# 5           0              1          40                      193
# 6           0              1          40                      193
# 7           0              1          40                      193
# 8           0              1          47                      195
# 9           0              1           7                      184
#
#    country_name  state_name        lat        lon  surface_total_in_m2  \
# 0             0           4 -34.610988 -58.363464                  0.0
# 1             0           3 -34.629923 -58.465820                  0.0
# 2             0           4 -34.589363 -58.412880                 53.0
# 3             0           4 -34.629923 -58.465820                 39.0
# 4             0           4 -34.629923 -58.465820                 51.0
# 5             0           4 -34.629923 -58.465820                 39.0
# 6             0           4 -34.629923 -58.465820                 39.0
# 7             0           4 -34.629923 -58.465820                 39.0
# 8             0           4 -34.578721 -58.457095                 67.0
# 9             0           4 -34.629923 -58.465820                 47.0
#
#    surface_covered_in_m2  floor  rooms    prediction
# 0             359.471588    1.0    1.0  7.633202e+05
# 1             359.471588    1.0    1.0  1.086648e+06
# 2              48.000000    1.0    1.0  1.044591e+05
# 3              39.000000    1.0    1.0  2.960344e+05
# 4              51.000000    1.0    1.0  2.537855e+05
# 5              39.000000    1.0    1.0  2.960344e+05
# 6              39.000000    1.0    1.0  2.960344e+05
# 7              39.000000    1.0    1.0  2.960344e+05
# 8              67.000000    1.0    1.0  1.638969e+05
# 9              47.000000    1.0    1.0  2.926145e+05

# %%
# guardo el file
output = pd.DataFrame( data={"id":test_df["id"], "price_usd":X_test_df['prediction']} )
output.to_csv( "../data/result/result_gbv02_"+str(now)+".csv", index=False, quoting=3 )
