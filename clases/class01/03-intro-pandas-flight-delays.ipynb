# %% [markdown]
# # Introducción al Análisis Exploratorio de Datos
#
# Es un enfoque que comprende un conjunto de tareas para analizar conjuntos de datos para poder encontrar sus principales caracteristicas.
#
# Estas tareas en general comprenden todo lo que tenemos que hacer desde que se formula una pregunta interesante, se reunen los datos y se desarrolla el proceso necesario para **poder responder esa pregunta**.
#
# Su Objetivo es:
#
# - Entender los datos.
# - Ver caracteristicas de los datos.
# - Detectar irregularidades (outliers) de los datos.
# - Obtener valores estadisticos de los datos.
# - Realizar visualizaciones rapidas que faciliten el proceso de exploracion.
#
# Usualmente el resultado del mismo suele ser un reporte o un notebook, que reune codigo y visualizaciones para llegar a ciertas **conclusiones o insights**.
#
# Es un proceso iterativo, que se retroalimenta.
#
# En general realizaremos el análisis del mismo sobre uno o varios Dataframes.

# %%
# magic function para hacer que los graficos de matplotlib se renderizen en el notebook.
# %matplotlib inline

import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('default') # haciendo los graficos un poco mas bonitos xD
plt.rcParams['figure.figsize'] = (15, 5)

# %% [markdown]
# ## Dataframes
#
# Conjunto de Datos en forma matricial (tabla) en don cada fila corresponde a una observacion (dato) y cada columna es un atributo correspondiente al dato (feature).
#
# Los Dataframes tienen columnas.
#
# Una columna es un vector de tamaño fijo de elementos de un mismo tipo acompañados de un indice para los mismos.
#
# Se pueden realizar muchas operaciones sobre una columna.
#
# operaciones matematicas o estadisticas sobre vectores como la:
#
# - sumatoria
# - promedio
# - mediana
# - varianza
# - desviación standard.
#
# Esto se puede aplicar una funcion a cada elemento de la columna (**map**) o aplicar una funcion a la columna entera (**apply**) en donde recibimos un vector (representando la columna) y podemos devolver un valor o un vector.

# %% [markdown]
# ## Pandas
#
# Implementacion de data frames (y otras estructuras de datos como Series) en python que provee herramientas para facilitar el analisis de datos en el mundo real.
#
# Es la implementacion que usaremos para dar nuestros primeros pasos con data frames y brindar herramientas para realizar un analisis exploratorio de datos.
#
# Mas informacion en: [https://pypi.python.org/pypi/pandas](https://pypi.python.org/pypi/pandas)
#
# Independientemente que la clase es una guia practica para comenzar a utilizar pandas, les recomendamos la siguiente documentacion:
#
# - **Basics**: [http://pandas.pydata.org/pandas-docs/stable/basics.htmlhttp://pandas.pydata.org/pandas-docs/stable/basics.html](http://pandas.pydata.org/pandas-docs/stable/basics.htmlhttp://pandas.pydata.org/pandas-docs/stable/basics.html)
# - **Data Merging**: [http://pandas.pydata.org/pandas-docs/stable/merging.html](http://pandas.pydata.org/pandas-docs/stable/merging.html)
# - **Split-Apply-Combine**: [http://pandas.pydata.org/pandas-docs/stable/groupby.html](http://pandas.pydata.org/pandas-docs/stable/groupby.html)
# - **Visualizacion**: [http://pandas.pydata.org/pandas-docs/stable/visualization.html](http://pandas.pydata.org/pandas-docs/stable/visualization.html)
# - **Pandas SQL Comparison**: [http://pandas.pydata.org/pandas-docs/stable/comparison_with_sql.html#compare-with-sql-join](http://pandas.pydata.org/pandas-docs/stable/comparison_with_sql.html)
#
#
# Una forma de pensar en un DataFrame es pensar en el objeto por el que estan compuestos, las series. Es por eso que podemos pensar en un DataFrame como un conjunto de objetos Serie que comparten un indice (los nombres de las columnas). Es por eso que para empezar vamos a introducir el concepto de Serie.

# %% [markdown]
# ### Series
#
# Una Series es un objeto unidimensional similar a un array, lista o columna en una tabla.
# Esta le va a asignar un indice con un label a aca elemento. Por default este sera numerico.

# %%
s = pd.Series(['This','is','a','Series'])
print(s)
#type(s)
# Out:
# 0      This
# 1        is
# 2         a
# 3    Series
# dtype: object

# %%
# o con un indice
s = pd.Series(['This','is','a','Series'], index=['A','B','C','D'])
print(s)
# Out:
# A      This
# B        is
# C         a
# D    Series
# dtype: object

# %% [markdown]
# Tambien pueden realizarse inicializaciones desde diccionarios, etc.

# %%
d = {'CABA': 10000, 'La Plata': 2000, 'Azul': 1000, 'Mar del Plata': 7000}
some_cities = pd.Series(d);
some_cities
# Out:
# Azul              1000
# CABA             10000
# La Plata          2000
# Mar del Plata     7000
# dtype: int64

# %%
# se puede acceder a un elemento en particular desde el indice
#some_cities['CABA']
type(some_cities[['La Plata','Mar del Plata']])
# Out:
# pandas.core.series.Series

# %% [markdown]
# O usar indexacion booleana

# %%
some_cities[some_cities <= 5000]
# Out:
# Azul        1000
# La Plata    2000
# dtype: int64

# %%
# veamos parcialmente que sucede
# de la operacion que realizamos sobre some_cities obtenemos una serie de True y False
some_cities <= 5000 
# que luego utilizamos sobre los valores correspondientes de some_cities para obtener los que cumplen
# este concepto se usa constantemente trabajando con pandas.
# Out:
# Azul              True
# CABA             False
# La Plata          True
# Mar del Plata    False
# dtype: bool

# %% [markdown]
# ## Analisis Exploratorio de Datos: Flight Delays
#
# Para comenzar a trabajar en la distintas operaciones que podemos realizar con un data frame vamos a trabajar con el siguiente set de datos:
#
# [https://www.kaggle.com/usdot/flight-delays](https://www.kaggle.com/usdot/flight-delays)
#
# El set de datos contiene informacion sobre retrasos de vuelos y cancelaciones durante el año 2015.

# %% [markdown]
# ### Carga de Informacion en un Dataframe
#
# Pandas soporta distintas fuentes de informacion en distintos formatos (desde archivos de csv, excel, hasta fuentes remotas como urls o bases de datos, etc.). En este caso vamos a cargar la informacion desde un CSV que hemos descargado previamente de kaggle. Esto lo podemos hacer con pandas con ```read_csv```.
#
# Inicialmente podremos ver parte del data frame para tener idea de la estructura del mismo.

# %%
# carga de un data frame
#flights = pd.read_csv('../data/flight-delays/flights.csv', low_memory=False)
flights = pd.read_csv('../data/flight-delays/flights.csv', low_memory=False)

# %%
# veamos la informacion general del dataframe.
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5819079 entries, 0 to 5819078
# Data columns (total 31 columns):
# YEAR                   int64
# MONTH                  int64
# DAY                    int64
# DAY_OF_WEEK            int64
# AIRLINE                object
# FLIGHT_NUMBER          int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# SCHEDULED_DEPARTURE    int64
# DEPARTURE_TIME         float64
# DEPARTURE_DELAY        float64
# TAXI_OUT               float64
# WHEELS_OFF             float64
# SCHEDULED_TIME         float64
# ELAPSED_TIME           float64
# AIR_TIME               float64
# DISTANCE               int64
# WHEELS_ON              float64
# TAXI_IN                float64
# SCHEDULED_ARRIVAL      int64
# ARRIVAL_TIME           float64
# ARRIVAL_DELAY          float64
# DIVERTED               int64
# CANCELLED              int64
# CANCELLATION_REASON    object
# AIR_SYSTEM_DELAY       float64
# SECURITY_DELAY         float64
# AIRLINE_DELAY          float64
# LATE_AIRCRAFT_DELAY    float64
# WEATHER_DELAY          float64
# dtypes: float64(16), int64(10), object(5)
# memory usage: 1.3+ GB

# %%
# vemos primeras filas del data frame
flights[:3]
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                  NaN
# 1         741.0           -9.0         0          0                  NaN
# 2         811.0            5.0         0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY
# 0            NaN
# 1            NaN
# 2            NaN
#
# [3 rows x 31 columns]

# %%
#podemos los primeros valores
flights.head(3)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                  NaN
# 1         741.0           -9.0         0          0                  NaN
# 2         811.0            5.0         0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY
# 0            NaN
# 1            NaN
# 2            NaN
#
# [3 rows x 31 columns]

# %%
#y los ultimos
flights.tail(10)
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819069  2015     12   31            4      B6           1248      N948JB
# 5819070  2015     12   31            4      B6             80      N584JB
# 5819071  2015     12   31            4      B6            802      N589JB
# 5819072  2015     12   31            4      B6             98      N607JB
# 5819073  2015     12   31            4      B6             66      N655JB
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 5819069            LAS                 JFK                 2359
# 5819070            RNO                 JFK                 2359
# 5819071            SLC                 MCO                 2359
# 5819072            DEN                 JFK                 2359
# 5819073            ABQ                 JFK                 2359
# 5819074            LAX                 BOS                 2359
# 5819075            JFK                 PSE                 2359
# 5819076            JFK                 SJU                 2359
# 5819077            MCO                 SJU                 2359
# 5819078            JFK                 BQN                 2359
#
#              ...        ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 5819069      ...              1020.0          159.0         0          0
# 5819070      ...               744.0          -21.0         0          0
# 5819071      ...               625.0           17.0         0          0
# 5819072      ...               519.0          -11.0         0          0
# 5819073      ...               549.0            3.0         0          0
# 5819074      ...               753.0          -26.0         0          0
# 5819075      ...               430.0          -16.0         0          0
# 5819076      ...               432.0           -8.0         0          0
# 5819077      ...               330.0          -10.0         0          0
# 5819078      ...               442.0            2.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 5819069                  NaN               0.0             0.0          159.0
# 5819070                  NaN               NaN             NaN            NaN
# 5819071                  NaN               1.0             0.0           16.0
# 5819072                  NaN               NaN             NaN            NaN
# 5819073                  NaN               NaN             NaN            NaN
# 5819074                  NaN               NaN             NaN            NaN
# 5819075                  NaN               NaN             NaN            NaN
# 5819076                  NaN               NaN             NaN            NaN
# 5819077                  NaN               NaN             NaN            NaN
# 5819078                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 5819069                  0.0            0.0
# 5819070                  NaN            NaN
# 5819071                  0.0            0.0
# 5819072                  NaN            NaN
# 5819073                  NaN            NaN
# 5819074                  NaN            NaN
# 5819075                  NaN            NaN
# 5819076                  NaN            NaN
# 5819077                  NaN            NaN
# 5819078                  NaN            NaN
#
# [10 rows x 31 columns]

# %%
flights.columns.values
# Out:
# Index(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY', 'TAXI_OUT',
#        'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
#        'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED', 'CANCELLATION_REASON',
#        'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'],
#       dtype='object')

# %%
# si queremos analizar cuales son los valores de las columnas podemos obtenerlos con .columns
for name in flights.columns.values:
    print (name)
# Out:
# YEAR
# MONTH
# DAY
# DAY_OF_WEEK
# AIRLINE
# FLIGHT_NUMBER
# TAIL_NUMBER
# ORIGIN_AIRPORT
# DESTINATION_AIRPORT
# SCHEDULED_DEPARTURE
# DEPARTURE_TIME
# DEPARTURE_DELAY
# TAXI_OUT
# WHEELS_OFF
# SCHEDULED_TIME
# ELAPSED_TIME
# AIR_TIME
# DISTANCE
# WHEELS_ON
# TAXI_IN
# SCHEDULED_ARRIVAL
# ARRIVAL_TIME
# ARRIVAL_DELAY
# DIVERTED
# CANCELLED
# CANCELLATION_REASON
# AIR_SYSTEM_DELAY
# SECURITY_DELAY
# AIRLINE_DELAY
# LATE_AIRCRAFT_DELAY
# WEATHER_DELAY

# %% [markdown]
# Por otro lado muchas veces es necesario hacer algunas modificaciones en la forma en la que se cargan los datos del CSV dependiendo del formato del mismo, esto se puede hacer por ejemplo para ver como convertir datos (por ejemplo formatos de fechas), hasta tipos de separador, etc.

# %%
# sin index_col
airports = pd.read_csv('../data/flight-delays/airports.csv', sep=',', encoding='utf-8')
airports.head()
# Out:
#   IATA_CODE                              AIRPORT         CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport    Allentown    PA     USA
# 1       ABI             Abilene Regional Airport      Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport  Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport     Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport       Albany    GA     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447

# %%
# por ejemplo se puede usar index_col para indicar un indice
airports = pd.read_csv('../data/flight-delays/airports.csv', sep=',', encoding='utf-8', index_col='IATA_CODE')
airports.head()
# Out:
#                                        AIRPORT         CITY STATE COUNTRY  \
# IATA_CODE
# ABE        Lehigh Valley International Airport    Allentown    PA     USA
# ABI                   Abilene Regional Airport      Abilene    TX     USA
# ABQ          Albuquerque International Sunport  Albuquerque    NM     USA
# ABR                  Aberdeen Regional Airport     Aberdeen    SD     USA
# ABY         Southwest Georgia Regional Airport       Albany    GA     USA
#
#            LATITUDE  LONGITUDE
# IATA_CODE
# ABE        40.65236  -75.44040
# ABI        32.41132  -99.68190
# ABQ        35.04022 -106.60919
# ABR        45.44906  -98.42183
# ABY        31.53552  -84.19447

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 322 entries, ABE to YUM
# Data columns (total 6 columns):
# AIRPORT      322 non-null object
# CITY         322 non-null object
# STATE        322 non-null object
# COUNTRY      322 non-null object
# LATITUDE     319 non-null float64
# LONGITUDE    319 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 17.6+ KB

# %%
airlines = pd.read_csv('../data/flight-delays/airlines.csv', sep=',', encoding='utf-8')
airlines.head()
# Out:
#   IATA_CODE                 AIRLINE
# 0        UA   United Air Lines Inc.
# 1        AA  American Airlines Inc.
# 2        US         US Airways Inc.
# 3        F9  Frontier Airlines Inc.
# 4        B6         JetBlue Airways

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 2 columns):
# IATA_CODE    14 non-null object
# AIRLINE      14 non-null object
# dtypes: object(2)
# memory usage: 304.0+ bytes

# %%
nj_airports = airports[airports['STATE'] == 'NJ']

# %%
type(nj_airports)
# Out:
# pandas.core.frame.DataFrame

# %%
nj_airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, ACY to TTN
# Data columns (total 6 columns):
# AIRPORT      3 non-null object
# CITY         3 non-null object
# STATE        3 non-null object
# COUNTRY      3 non-null object
# LATITUDE     3 non-null float64
# LONGITUDE    3 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 168.0+ bytes

# %% [markdown]
# ### Verificacion de Calidad de Datos
#
# Algunas verificaciones que son utiles para ver la consistencia de los datos, en particular si vienen de una fuente de ese tipo.
#
# Podemos verificar las dimensiones del data frame (via ```.shape```), si existen valores nulos (via ```.insnull```) en el mismo y metricas generales de las columnas o features del data frame que podemos analizar via ```.describe```

# %%
print(flights.shape)
print(airports.shape)
print(airlines.shape)
# Out:
# (5819079, 31)
# (322, 6)
# (14, 2)

# %%
#print(airlines.isnull().any())
#print(airports.isnull().any())

# %%
print(flights.isnull().any())
# Out:
# YEAR                   False
# MONTH                  False
# DAY                    False
# DAY_OF_WEEK            False
# AIRLINE                False
# FLIGHT_NUMBER          False
# TAIL_NUMBER             True
# ORIGIN_AIRPORT         False
# DESTINATION_AIRPORT    False
# SCHEDULED_DEPARTURE    False
# DEPARTURE_TIME          True
# DEPARTURE_DELAY         True
# TAXI_OUT                True
# WHEELS_OFF              True
# SCHEDULED_TIME          True
# ELAPSED_TIME            True
# AIR_TIME                True
# DISTANCE               False
# WHEELS_ON               True
# TAXI_IN                 True
# SCHEDULED_ARRIVAL      False
# ARRIVAL_TIME            True
# ARRIVAL_DELAY           True
# DIVERTED               False
# CANCELLED              False
# CANCELLATION_REASON     True
# AIR_SYSTEM_DELAY        True
# SECURITY_DELAY          True
# AIRLINE_DELAY           True
# LATE_AIRCRAFT_DELAY     True
# WEATHER_DELAY           True
# dtype: bool

# %%
flights.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE                      0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# WEATHER_DELAY          4755640
# dtype: int64

# %%
# metricas generales de las columnas o features del data frame que podemos analizar via .describe
print(flights.describe())
# Out:
#             YEAR         MONTH           DAY   DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  5819079.0  5.819079e+06  5.819079e+06  5.819079e+06   5.819079e+06
# mean      2015.0  6.524085e+00  1.570459e+01  3.926941e+00   2.173093e+03
# std          0.0  3.405137e+00  8.783425e+00  1.988845e+00   1.757064e+03
# min       2015.0  1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# 25%       2015.0  4.000000e+00  8.000000e+00  2.000000e+00   7.300000e+02
# 50%       2015.0  7.000000e+00  1.600000e+01  4.000000e+00   1.690000e+03
# 75%       2015.0  9.000000e+00  2.300000e+01  6.000000e+00   3.230000e+03
# max       2015.0  1.200000e+01  3.100000e+01  7.000000e+00   9.855000e+03
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         5.819079e+06    5.732926e+06     5.732926e+06  5.730032e+06
# mean          1.329602e+03    1.335204e+03     9.370158e+00  1.607166e+01
# std           4.837518e+02    4.964233e+02     3.708094e+01  8.895574e+00
# min           1.000000e+00    1.000000e+00    -8.200000e+01  1.000000e+00
# 25%           9.170000e+02    9.210000e+02    -5.000000e+00  1.100000e+01
# 50%           1.325000e+03    1.330000e+03    -2.000000e+00  1.400000e+01
# 75%           1.730000e+03    1.740000e+03     7.000000e+00  1.900000e+01
# max           2.359000e+03    2.400000e+03     1.988000e+03  2.250000e+02
#
#          WHEELS_OFF      ...        SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# count  5.730032e+06      ...             5.819079e+06  5.726566e+06
# mean   1.357171e+03      ...             1.493808e+03  1.476491e+03
# std    4.980094e+02      ...             5.071647e+02  5.263197e+02
# min    1.000000e+00      ...             1.000000e+00  1.000000e+00
# 25%    9.350000e+02      ...             1.110000e+03  1.059000e+03
# 50%    1.343000e+03      ...             1.520000e+03  1.512000e+03
# 75%    1.754000e+03      ...             1.918000e+03  1.917000e+03
# max    2.400000e+03      ...             2.400000e+03  2.400000e+03
#
#        ARRIVAL_DELAY      DIVERTED     CANCELLED  AIR_SYSTEM_DELAY  \
# count   5.714008e+06  5.819079e+06  5.819079e+06      1.063439e+06
# mean    4.407057e+00  2.609863e-03  1.544643e-02      1.348057e+01
# std     3.927130e+01  5.102012e-02  1.233201e-01      2.800368e+01
# min    -8.700000e+01  0.000000e+00  0.000000e+00      0.000000e+00
# 25%    -1.300000e+01  0.000000e+00  0.000000e+00      0.000000e+00
# 50%    -5.000000e+00  0.000000e+00  0.000000e+00      2.000000e+00
# 75%     8.000000e+00  0.000000e+00  0.000000e+00      1.800000e+01
# max     1.971000e+03  1.000000e+00  1.000000e+00      1.134000e+03
#
#        SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# count    1.063439e+06   1.063439e+06         1.063439e+06   1.063439e+06
# mean     7.615387e-02   1.896955e+01         2.347284e+01   2.915290e+00
# std      2.143460e+00   4.816164e+01         4.319702e+01   2.043334e+01
# min      0.000000e+00   0.000000e+00         0.000000e+00   0.000000e+00
# 25%      0.000000e+00   0.000000e+00         0.000000e+00   0.000000e+00
# 50%      0.000000e+00   2.000000e+00         3.000000e+00   0.000000e+00
# 75%      0.000000e+00   1.900000e+01         2.900000e+01   0.000000e+00
# max      5.730000e+02   1.971000e+03         1.331000e+03   1.211000e+03
#
# [8 rows x 26 columns]

# %%
#algunas verificaciones

cancelled_flights_count = flights['CANCELLED'].sum()
#sobre el total de filas restamos aquellas que no tiene una cancelacion
# .shape nos devuelve la dimensionalidad del data frame (filas x columnas).
flights_with_cancellation_reason = flights.shape[0] - flights.CANCELLATION_REASON.isnull().sum()

# %%
# solo vuelos cancelados tienen razon de cancelacion?
print(cancelled_flights_count)
print(flights_with_cancellation_reason)
# Out:
# 89884
# 89884

# %% [markdown]
# ### Cantidad de Vuelos a Aeropuertos de Destino

# %%
flights['DESTINATION_AIRPORT'][:3] #realizamos una proyeccion
# Out:
# 0    SEA
# 1    PBI
# 2    CLT
# Name: DESTINATION_AIRPORT, dtype: object

# %%
count_flights_to_airports = flights['DESTINATION_AIRPORT'].value_counts()

# %%
count_flights_to_airports
# Out:
# ATL      346904
# ORD      285906
# DFW      239582
# DEN      196010
# LAX      194696
# SFO      147966
# PHX      146812
# IAH      146683
# LAS      133198
# MSP      112128
# MCO      110980
# SEA      110907
# DTW      108398
# BOS      107851
# EWR      101830
# CLT      100322
# LGA       99581
# SLC       97193
# JFK       93809
# BWI       86085
# MDW       80884
# DCA       73799
# FLL       73599
# SAN       70207
# MIA       69324
# PHL       66017
# TPA       63914
# DAL       59703
# HOU       52041
# BNA       47568
#           ...
# 12888        53
# 11525        53
# 14109        53
# 12255        53
# 12343        53
# 10333        53
# 11587        53
# 10739        53
# 12177        53
# 13127        53
# 10918        53
# 11447        48
# 13964        36
# ITH          35
# 10170        31
# 12016        31
# 11097        31
# 10154        28
# 10581        26
# 13459        26
# 12265        22
# 12094        20
# 15497        14
# 14025        13
# 13541        11
# 10165         9
# 14222         9
# 13502         7
# 11503         3
# 10666         1
# Name: DESTINATION_AIRPORT, Length: 629, dtype: int64

# %%
# %matplotlib inline
#%matplotlib notebook
# top 20
count_flights_to_airports[:5].plot('bar')

# %%
airports[airports.index == 'ITH']
# Out:
#                                     AIRPORT    CITY STATE COUNTRY  LATITUDE  \
# IATA_CODE
# ITH        Ithaca Tompkins Regional Airport  Ithaca    NY     USA  42.49103
#
#            LONGITUDE
# IATA_CODE
# ITH        -76.45844

# %% [markdown]
# ### Que sucede yendo desde Los Angeles a Atlanta

# %%
# subsetting, filtering o seleccion
atl_flights = flights[flights['DESTINATION_AIRPORT'] == "ATL"]
atl_flights[['AIRLINE','DESTINATION_AIRPORT']].describe()
# Out:
#        AIRLINE DESTINATION_AIRPORT
# count   346904              346904
# unique      11                   1
# top         DL                 ATL
# freq    221673              346904

# %%
atl_flights['DESTINATION_AIRPORT'].describe()
# Out:
# count     346904
# unique         1
# top          ATL
# freq      346904
# Name: DESTINATION_AIRPORT, dtype: object

# %%
# para entender como funciona veamos la expresion
flights['DESTINATION_AIRPORT'] == "ATL"
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9           True
# 10          True
# 11         False
# 12         False
# 13          True
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 5819049    False
# 5819050    False
# 5819051    False
# 5819052    False
# 5819053    False
# 5819054    False
# 5819055    False
# 5819056    False
# 5819057    False
# 5819058    False
# 5819059    False
# 5819060    False
# 5819061    False
# 5819062    False
# 5819063    False
# 5819064    False
# 5819065    False
# 5819066    False
# 5819067    False
# 5819068    False
# 5819069    False
# 5819070    False
# 5819071    False
# 5819072    False
# 5819073    False
# 5819074    False
# 5819075    False
# 5819076    False
# 5819077    False
# 5819078    False
# Name: DESTINATION_AIRPORT, Length: 5819079, dtype: bool

# %%
atl_flights['AIRLINE'].value_counts()
# Out:
# DL    221673
# EV     57056
# WN     39508
# AA      7499
# F9      4492
# NK      4372
# OO      4227
# UA      3412
# US      2940
# MQ      1295
# AS       430
# Name: AIRLINE, dtype: int64

# %%
airlines[airlines.IATA_CODE == 'WN']
# Out:
#   IATA_CODE                 AIRLINE
# 8        WN  Southwest Airlines Co.

# %%
# al indexar nuestro data frame con la columna de True y False solamente obtendremos aquellos con false.
# tambien es posible adicionar condiciones con operadores logicos
is_from_lax = flights['ORIGIN_AIRPORT'] == "LAX"
is_to_atl = flights['DESTINATION_AIRPORT'] == "ATL"
lax_to_atl_flights = flights[is_from_lax & is_to_atl]
lax_to_atl_flights.head()
# Out:
#       YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 268   2015      1    1            4      DL           2154      N813DN
# 1269  2015      1    1            4      DL            369      N144DA
# 2425  2015      1    1            4      WN           1191      N7812G
# 2707  2015      1    1            4      DL             80      N845MH
# 4728  2015      1    1            4      DL            101      N826DN
#
#      ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 268             LAX                 ATL                  600      ...
# 1269            LAX                 ATL                  730      ...
# 2425            LAX                 ATL                  900      ...
# 2707            LAX                 ATL                  915      ...
# 4728            LAX                 ATL                 1130      ...
#
#       ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 268         1250.0          -20.0         0          0                  NaN
# 1269        1423.0          -19.0         0          0                  NaN
# 2425        1621.0           11.0         0          0                  NaN
# 2707        1609.0          -21.0         0          0                  NaN
# 4728        1856.0           16.0         0          0                  NaN
#
#       AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 268                NaN             NaN            NaN                  NaN
# 1269               NaN             NaN            NaN                  NaN
# 2425               NaN             NaN            NaN                  NaN
# 2707               NaN             NaN            NaN                  NaN
# 4728               0.0             0.0           16.0                  0.0
#
#       WEATHER_DELAY
# 268             NaN
# 1269            NaN
# 2425            NaN
# 2707            NaN
# 4728            0.0
#
# [5 rows x 31 columns]

# %%
lax_to_atl_flights['DESTINATION_AIRPORT'].describe()
# Out:
# count     5673
# unique       1
# top        ATL
# freq      5673
# Name: DESTINATION_AIRPORT, dtype: object

# %%
lax_to_atl_flights['CANCELLED'].value_counts()
# Out:
# 0    5646
# 1      27
# Name: CANCELLED, dtype: int64

# %%
# deberia darme 27
lax_to_atl_flights['CANCELLED'].sum()
# Out:
# 27

# %%
fig = plt.figure(figsize=(10,4));

flights['CANCELLATION_REASON'].value_counts().plot('bar')

# %%
flights['CANCELLATION_REASON'].value_counts()
# Out:
# B    48851
# A    25262
# C    15749
# D       22
# Name: CANCELLATION_REASON, dtype: int64

# %% [markdown]
# ## Que Aeropuerto de Origen tiene las mayor cantidad de cancelaciones

# %%
# filtro primero los cancelados
cancelled_flights = flights[flights['CANCELLED'] == 1]
# luego agrupo por origin
cancelled_flights['ORIGIN_AIRPORT'].value_counts()[:10]
# Out:
# ORD    8548
# DFW    6254
# LGA    4531
# EWR    3110
# BOS    2654
# ATL    2557
# LAX    2164
# SFO    2148
# IAH    2130
# DEN    2123
# Name: ORIGIN_AIRPORT, dtype: int64

# %%
#cuento los totales
flights_per_origin_count = flights['ORIGIN_AIRPORT'].count()
flights_per_origin_count
# Out:
# 5819079

# %%
# obtengo la cantidad de datos por origen
flights_per_origin_count = flights['ORIGIN_AIRPORT'].value_counts()
#filtro aquellos que tienen mas de 37392 vuelos por origen
flights_per_origin_count = flights_per_origin_count[flights_per_origin_count >= 37392]
flights_per_origin_count.tail()
# Out:
# OAK    42316
# AUS    42067
# MSY    38804
# MCI    38665
# SJC    38200
# Name: ORIGIN_AIRPORT, dtype: int64

# %%
# de los cancelados, cuento la cantidad de datos por cada origen
flights_cancelled_per_origin = cancelled_flights['ORIGIN_AIRPORT'].value_counts()
flights_cancelled_per_origin.tail()
# Out:
# 12323    1
# 11921    1
# 13970    1
# 11587    1
# 10257    1
# Name: ORIGIN_AIRPORT, dtype: int64

# %%
is_cancelled = flights['CANCELLED'] == 1
cancelled_flights = flights[is_cancelled]
cancelled_flights.head()
# Out:
#     YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 32  2015      1    1            4      AS            136      N431AS
# 42  2015      1    1            4      AA           2459      N3BDAA
# 68  2015      1    1            4      OO           5254      N746SK
# 82  2015      1    1            4      MQ           2859      N660MQ
# 90  2015      1    1            4      OO           5460      N583SW
#
#    ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 32            ANC                 SEA                  135      ...
# 42            PHX                 DFW                  200      ...
# 68            MAF                 IAH                  510      ...
# 82            SGF                 DFW                  525      ...
# 90            RDD                 SFO                  530      ...
#
#     ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 32           NaN            NaN         0          1                    A
# 42           NaN            NaN         0          1                    B
# 68           NaN            NaN         0          1                    B
# 82           NaN            NaN         0          1                    B
# 90           NaN            NaN         0          1                    A
#
#     AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 32               NaN             NaN            NaN                  NaN
# 42               NaN             NaN            NaN                  NaN
# 68               NaN             NaN            NaN                  NaN
# 82               NaN             NaN            NaN                  NaN
# 90               NaN             NaN            NaN                  NaN
#
#     WEATHER_DELAY
# 32            NaN
# 42            NaN
# 68            NaN
# 82            NaN
# 90            NaN
#
# [5 rows x 31 columns]

# %%
cancellation_ratio = flights_cancelled_per_origin.astype(float) / flights_per_origin_count.astype(float)
# muestro solo los que son no nulos
cancellation_ratio[cancellation_ratio.notnull()].head()
# Out:
# ATL    0.007372
# AUS    0.013740
# BNA    0.022404
# BOS    0.024609
# BWI    0.017809
# Name: ORIGIN_AIRPORT, dtype: float64

# %%
top_20_cancellation_ratio = cancellation_ratio.sort_values(ascending=False)[:20]

# %%
top_20_cancellation_ratio
# Out:
# LGA    0.045490
# EWR    0.030559
# ORD    0.029900
# DCA    0.027468
# DFW    0.026107
# BOS    0.024609
# MDW    0.024219
# BNA    0.022404
# JFK    0.020488
# BWI    0.017809
# PHL    0.016268
# HOU    0.014873
# IAH    0.014527
# SFO    0.014513
# DAL    0.014238
# STL    0.013777
# AUS    0.013740
# OAK    0.013541
# DTW    0.011705
# SJC    0.011466
# Name: ORIGIN_AIRPORT, dtype: float64

# %%
flights_per_origin_count['LGA']
# Out:
# 99605

# %%
airports[airports.index == 'LGA']
# Out:
#                                            AIRPORT      CITY STATE COUNTRY  \
# IATA_CODE
# LGA        LaGuardia Airport (Marine Air Terminal)  New York    NY     USA
#
#            LATITUDE  LONGITUDE
# IATA_CODE
# LGA        40.77724  -73.87261

# %%
# asi funciona reset_index: agarra como columna el valor del agrupado. Es decir, "destranforma" el indice
airports[airports.index == 'LGA'].reset_index()
# Out:
#   IATA_CODE                                  AIRPORT      CITY STATE COUNTRY  \
# 0       LGA  LaGuardia Airport (Marine Air Terminal)  New York    NY     USA
#
#    LATITUDE  LONGITUDE
# 0  40.77724  -73.87261

# %%
# comentar uso media
flights_per_origin_count.describe()
# Out:
# count        38.000000
# mean     104240.605263
# std       69855.604314
# min       38200.000000
# 25%       53956.250000
# 50%       89945.000000
# 75%      111833.250000
# max      346836.000000
# Name: ORIGIN_AIRPORT, dtype: float64

# %% [markdown]
# ### Cancelaciones por dia de la Semana

# %%
# split-apply-combine
flights.columns.values
# Out:
# array(['YEAR', 'MONTH', 'DAY', 'DAY_OF_WEEK', 'AIRLINE', 'FLIGHT_NUMBER',
#        'TAIL_NUMBER', 'ORIGIN_AIRPORT', 'DESTINATION_AIRPORT',
#        'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'DEPARTURE_DELAY',
#        'TAXI_OUT', 'WHEELS_OFF', 'SCHEDULED_TIME', 'ELAPSED_TIME',
#        'AIR_TIME', 'DISTANCE', 'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL',
#        'ARRIVAL_TIME', 'ARRIVAL_DELAY', 'DIVERTED', 'CANCELLED',
#        'CANCELLATION_REASON', 'AIR_SYSTEM_DELAY', 'SECURITY_DELAY',
#        'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 'WEATHER_DELAY'], dtype=object)

# %%
day_of_week = flights[['MONTH','CANCELLED']]
day_of_week.head()
# Out:
#    MONTH  CANCELLED
# 0      1          0
# 1      1          0
# 2      1          0
# 3      1          0
# 4      1          0

# %%
day_of_week_counts = day_of_week.groupby('MONTH')
day_of_week_counts.head()
# Out:
#          MONTH  CANCELLED
# 0            1          0
# 1            1          0
# 2            1          0
# 3            1          0
# 4            1          0
# 469968       2          0
# 469969       2          0
# 469970       2          0
# 469971       2          0
# 469972       2          0
# 899159       3          1
# 899160       3          0
# 899161       3          0
# 899162       3          0
# 899163       3          0
# 1403471      4          0
# 1403472      4          0
# 1403473      4          0
# 1403474      4          0
# 1403475      4          0
# 1888622      5          0
# 1888623      5          0
# 1888624      5          0
# 1888625      5          0
# 1888626      5          0
# 2385615      6          0
# 2385616      6          0
# 2385617      6          0
# 2385618      6          0
# 2385619      6          0
# 2889512      7          0
# 2889513      7          0
# 2889514      7          0
# 2889515      7          0
# 2889516      7          0
# 3410230      8          0
# 3410231      8          0
# 3410232      8          0
# 3410233      8          0
# 3410234      8          0
# 3920766      9          0
# 3920767      9          0
# 3920768      9          0
# 3920769      9          0
# 3920770      9          0
# 4385712     10          0
# 4385713     10          0
# 4385714     10          0
# 4385715     10          0
# 4385716     10          0
# 4871877     11          0
# 4871878     11          0
# 4871879     11          0
# 4871880     11          0
# 4871881     11          1
# 5339849     12          0
# 5339850     12          0
# 5339851     12          0
# 5339852     12          0
# 5339853     12          0

# %%
day_of_week_counts = day_of_week.groupby('MONTH').aggregate(sum)
#day_of_week_counts.index = ['Enero', 'Martes', 'Miercoles', 'Jueves', 'Viernes', 'Sabado', 'Domingo']
day_of_week_counts
# Out:
#        CANCELLED
# MONTH
# 1          11982
# 2          20517
# 3          11002
# 4           4520
# 5           5694
# 6           9120
# 7           4806
# 8           5052
# 9           2075
# 10          2454
# 11          4599
# 12          8063

# %%
# es lo mismo que 
my_data_of_week = day_of_week.groupby('MONTH').sum()
#day_of_week_counts.index = ['Enero', 'Martes', 'Miercoles', 'Jueves',

# %%
# y el cambio el indice
my_data_of_week.index = ['Enero', 'Febrero', 'Marzo', 'Abril','Mayo','Junio','Julio','Agosto','S','O','N','D']
my_data_of_week
# Out:
#          CANCELLED
# Enero        11982
# Febrero      20517
# Marzo        11002
# Abril         4520
# Mayo          5694
# Junio         9120
# Julio         4806
# Agosto        5052
# S             2075
# O             2454
# N             4599
# D             8063

# %%
day_of_week_counts.plot(kind='bar')

# %%
day_of_week_counts.plot(kind='area')

# %%
operated  = flights[['MONTH','CANCELLED']][flights['CANCELLED'] == 0].groupby('MONTH').count() # operated
cancelled = flights[['MONTH','CANCELLED']][flights['CANCELLED'] != 0].groupby('MONTH').count() # cancelled

# %%
operated
# Out:
#        CANCELLED
# MONTH
# 1         457986
# 2         408674
# 3         493310
# 4         480631
# 5         491299
# 6         494777
# 7         515912
# 8         505484
# 9         462871
# 10        483711
# 11        463373
# 12        471167

# %%
# cual es la diferencia con sum?
flights[['MONTH','CANCELLED']][flights['CANCELLED'] == 0].groupby('MONTH').count() # operated
# la diferencia reside en que sum suma el contenido de la fila, en cambio count cuenta la cantidad registros
# Out:
#        CANCELLED
# MONTH
# 1         457986
# 2         408674
# 3         493310
# 4         480631
# 5         491299
# 6         494777
# 7         515912
# 8         505484
# 9         462871
# 10        483711
# 11        463373
# 12        471167

# %%
# entonces esto si deberia ser igual!
flights[['MONTH','CANCELLED']][flights['CANCELLED'] != 0].groupby('MONTH').sum() == flights[['MONTH','CANCELLED']][flights['CANCELLED'] != 0].groupby('MONTH').count()
# Out:
#       CANCELLED
# MONTH
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
# 6          True
# 7          True
# 8          True
# 9          True
# 10         True
# 11         True
# 12         True

# %%
operated.rename(columns={'CANCELLED': 'OPERATED'}, inplace=True)
operated
# Out:
#        OPERATED
# MONTH
# 1        457986
# 2        408674
# 3        493310
# 4        480631
# 5        491299
# 6        494777
# 7        515912
# 8        505484
# 9        462871
# 10       483711
# 11       463373
# 12       471167

# %%
cancelled
# Out:
#        CANCELLED
# MONTH
# 1          11982
# 2          20517
# 3          11002
# 4           4520
# 5           5694
# 6           9120
# 7           4806
# 8           5052
# 9           2075
# 10          2454
# 11          4599
# 12          8063

# %%
#merge por index, inner join
operated_and_cancelled = pd.merge(operated, cancelled, right_index=True, left_index=True)
operated_and_cancelled
# Out:
#        OPERATED  CANCELLED
# MONTH
# 1        457986      11982
# 2        408674      20517
# 3        493310      11002
# 4        480631       4520
# 5        491299       5694
# 6        494777       9120
# 7        515912       4806
# 8        505484       5052
# 9        462871       2075
# 10       483711       2454
# 11       463373       4599
# 12       471167       8063

# %%
operated_and_cancelled.plot(kind="area", stacked=False)

# %%
operated_and_cancelled.plot(kind="area", stacked=True)

# %%
operated_and_cancelled.plot(kind="bar", stacked=True)

# %% [markdown]
# Nota: Reutilizar analisis sobre MONTH

# %% [markdown]
# ### Utilizando los nombres de las Aerolineas

# %%
# left join
flights_with_airlines = pd.merge(flights, airlines, left_on='AIRLINE', right_on='IATA_CODE', how='left')

# %%
flights_with_airlines.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4        AS             98      N407AS
# 1  2015      1    1            4        AA           2336      N3KUAA
# 2  2015      1    1            4        US            840      N171US
# 3  2015      1    1            4        AA            258      N3HYAA
# 4  2015      1    1            4        AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0            ANC                 SEA                    5
# 1            LAX                 PBI                   10
# 2            SFO                 CLT                   20
# 3            LAX                 MIA                   20
# 4            SEA                 ANC                   25
#
#             ...            DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0           ...                   0          0                  NaN
# 1           ...                   0          0                  NaN
# 2           ...                   0          0                  NaN
# 3           ...                   0          0                  NaN
# 4           ...                   0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
# 3               NaN             NaN            NaN                  NaN
# 4               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY  IATA_CODE               AIRLINE_y
# 0            NaN         AS    Alaska Airlines Inc.
# 1            NaN         AA  American Airlines Inc.
# 2            NaN         US         US Airways Inc.
# 3            NaN         AA  American Airlines Inc.
# 4            NaN         AS    Alaska Airlines Inc.
#
# [5 rows x 33 columns]

# %%
#axis indica si se aplica sobre el indice o las columnas.
flights_with_airlines.drop('IATA_CODE', axis=1, inplace=True)
flights_with_airlines.rename(columns={'AIRLINE_x': 'AIRLINE_CODE','AIRLINE_y': 'AIRLINE'}, inplace=True)

# %%
flights_with_airlines.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_CODE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4           AS             98      N407AS
# 1  2015      1    1            4           AA           2336      N3KUAA
# 2  2015      1    1            4           US            840      N171US
# 3  2015      1    1            4           AA            258      N3HYAA
# 4  2015      1    1            4           AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0            ANC                 SEA                    5
# 1            LAX                 PBI                   10
# 2            SFO                 CLT                   20
# 3            LAX                 MIA                   20
# 4            SEA                 ANC                   25
#
#             ...            ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0           ...                    -22.0         0          0
# 1           ...                     -9.0         0          0
# 2           ...                      5.0         0          0
# 3           ...                     -9.0         0          0
# 4           ...                    -21.0         0          0
#
#    CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 0                  NaN               NaN             NaN            NaN
# 1                  NaN               NaN             NaN            NaN
# 2                  NaN               NaN             NaN            NaN
# 3                  NaN               NaN             NaN            NaN
# 4                  NaN               NaN             NaN            NaN
#
#    LATE_AIRCRAFT_DELAY  WEATHER_DELAY                 AIRLINE
# 0                  NaN            NaN    Alaska Airlines Inc.
# 1                  NaN            NaN  American Airlines Inc.
# 2                  NaN            NaN         US Airways Inc.
# 3                  NaN            NaN  American Airlines Inc.
# 4                  NaN            NaN    Alaska Airlines Inc.
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Cantidad de Vuelos por Aerolinea

# %%
flights_with_airlines.groupby(['AIRLINE']).head()
# Out:
#       YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_CODE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0     2015      1    1            4           AS             98      N407AS
# 1     2015      1    1            4           AA           2336      N3KUAA
# 2     2015      1    1            4           US            840      N171US
# 3     2015      1    1            4           AA            258      N3HYAA
# 4     2015      1    1            4           AS            135      N527AS
# 5     2015      1    1            4           DL            806      N3730B
# 6     2015      1    1            4           NK            612      N635NK
# 7     2015      1    1            4           US           2013      N584UW
# 8     2015      1    1            4           AA           1112      N3LAAA
# 9     2015      1    1            4           DL           1173      N826DN
# 10    2015      1    1            4           DL           2336      N958DN
# 11    2015      1    1            4           AA           1674      N853AA
# 12    2015      1    1            4           DL           1434      N547US
# 13    2015      1    1            4           DL           2324      N3751B
# 15    2015      1    1            4           AS            108      N309AS
# 17    2015      1    1            4           UA           1197      N78448
# 18    2015      1    1            4           AS            122      N413AS
# 20    2015      1    1            4           NK            520      N525NK
# 21    2015      1    1            4           AA            371      N3GXAA
# 22    2015      1    1            4           NK            214      N632NK
# 25    2015      1    1            4           UA           1545      N76517
# 26    2015      1    1            4           AS            130      N457AS
# 27    2015      1    1            4           NK            597      N528NK
# 28    2015      1    1            4           US            413      N571UW
# 30    2015      1    1            4           NK            168      N629NK
# 35    2015      1    1            4           HA             17      N389HA
# 36    2015      1    1            4           US            617      N804AW
# 37    2015      1    1            4           UA           1528      N76519
# 39    2015      1    1            4           B6            304      N607JB
# 45    2015      1    1            4           B6           1990      N597JB
# ...    ...    ...  ...          ...          ...            ...         ...
# 66    2015      1    1            4           OO           7404      N8982A
# 67    2015      1    1            4           OO           7419      N445SW
# 68    2015      1    1            4           OO           5254      N746SK
# 72    2015      1    1            4           EV           4354      N12142
# 76    2015      1    1            4           EV           4685      N26545
# 77    2015      1    1            4           EV           5583      N882AS
# 78    2015      1    1            4           OO           5484      N824AS
# 80    2015      1    1            4           HA            103      N477HA
# 81    2015      1    1            4           EV           5187      N720EV
# 82    2015      1    1            4           MQ           2859      N660MQ
# 87    2015      1    1            4           EV           5764      N832AS
# 88    2015      1    1            4           F9           1279      N918FR
# 114   2015      1    1            4           F9            161      N905FR
# 126   2015      1    1            4           F9            365      N218FR
# 127   2015      1    1            4           F9            117      N933FR
# 128   2015      1    1            4           MQ           2926      N932MQ
# 147   2015      1    1            4           MQ           3534      N925MQ
# 155   2015      1    1            4           WN            526      N742SW
# 166   2015      1    1            4           MQ           3161      N5PBMQ
# 184   2015      1    1            4           WN           4122      N486WN
# 185   2015      1    1            4           WN           4822      N293WN
# 186   2015      1    1            4           WN           2215      N249WN
# 187   2015      1    1            4           WN            676      N630WN
# 297   2015      1    1            4           F9            865         NaN
# 306   2015      1    1            4           MQ           2898      N514MQ
# 707   2015      1    1            4           VX            922      N361VA
# 846   2015      1    1            4           VX            399      N852VA
# 847   2015      1    1            4           VX            897      N845VA
# 985   2015      1    1            4           VX             12      N842VA
# 1246  2015      1    1            4           VX            404      N621VA
#
#      ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  \
# 0               ANC                 SEA                    5
# 1               LAX                 PBI                   10
# 2               SFO                 CLT                   20
# 3               LAX                 MIA                   20
# 4               SEA                 ANC                   25
# 5               SFO                 MSP                   25
# 6               LAS                 MSP                   25
# 7               LAX                 CLT                   30
# 8               SFO                 DFW                   30
# 9               LAS                 ATL                   30
# 10              DEN                 ATL                   30
# 11              LAS                 MIA                   35
# 12              LAX                 MSP                   35
# 13              SLC                 ATL                   40
# 15              ANC                 SEA                   45
# 17              SFO                 IAH                   48
# 18              ANC                 PDX                   50
# 20              LAS                 MCI                   55
# 21              SEA                 MIA                  100
# 22              LAS                 DFW                  103
# 25              LAX                 IAH                  115
# 26              FAI                 SEA                  115
# 27              MSP                 FLL                  115
# 28              LAS                 CLT                  120
# 30              PHX                 ORD                  125
# 35              LAS                 HNL                  145
# 36              ANC                 PHX                  152
# 37              SJU                 EWR                  154
# 39              SJU                 JFK                  155
# 45              SJU                 EWR                  206
# ...             ...                 ...                  ...
# 66              HIB                 MSP                  510
# 67              ABR                 MSP                  510
# 68              MAF                 IAH                  510
# 72              MKE                 IAH                  515
# 76              BRO                 IAH                  520
# 77              VPS                 ATL                  520
# 78              BOI                 SFO                  520
# 80              HNL                 LIH                  523
# 81              BNA                 ATL                  525
# 82              SGF                 DFW                  525
# 87              SBN                 ORD                  530
# 88              PHL                 MCO                  530
# 114             MSN                 DEN                  544
# 126             MKE                 DEN                  545
# 127             MSP                 DEN                  545
# 128             CHS                 DFW                  545
# 147             ABI                 DFW                  550
# 155             SFO                 DEN                  555
# 166             XNA                 DFW                  555
# 184             BOS                 BWI                  600
# 185             LAS                 BWI                  600
# 186             ABQ                 HOU                  600
# 187             PHX                 SLC                  600
# 297             MSO                 DEN                  600
# 306             MAF                 DFW                  600
# 707             SFO                 LAX                  645
# 846             JFK                 LAX                  700
# 847             LAS                 SFO                  700
# 985             SFO                 JFK                  705
# 1246            LAX                 JFK                  730
#
#                   ...               ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0                 ...                       -22.0         0          0
# 1                 ...                        -9.0         0          0
# 2                 ...                         5.0         0          0
# 3                 ...                        -9.0         0          0
# 4                 ...                       -21.0         0          0
# 5                 ...                         8.0         0          0
# 6                 ...                       -17.0         0          0
# 7                 ...                       -10.0         0          0
# 8                 ...                       -13.0         0          0
# 9                 ...                       -15.0         0          0
# 10                ...                       -30.0         0          0
# 11                ...                       -10.0         0          0
# 12                ...                        -4.0         0          0
# 13                ...                       -22.0         0          0
# 15                ...                       -14.0         0          0
# 17                ...                        -7.0         0          0
# 18                ...                       -18.0         0          0
# 20                ...                         6.0         0          0
# 21                ...                         1.0         0          0
# 22                ...                        -1.0         0          0
# 25                ...                       -11.0         0          0
# 26                ...                        -3.0         0          0
# 27                ...                        25.0         0          0
# 28                ...                       -31.0         0          0
# 30                ...                        43.0         0          0
# 35                ...                        15.0         0          0
# 36                ...                       -10.0         0          0
# 37                ...                       -11.0         0          0
# 39                ...                        11.0         0          0
# 45                ...                         4.0         0          0
# ...               ...                         ...       ...        ...
# 66                ...                         0.0         0          0
# 67                ...                        -4.0         0          0
# 68                ...                         NaN         0          1
# 72                ...                        13.0         0          0
# 76                ...                        -5.0         0          0
# 77                ...                       -15.0         0          0
# 78                ...                         3.0         0          0
# 80                ...                       -12.0         0          0
# 81                ...                         5.0         0          0
# 82                ...                         NaN         0          1
# 87                ...                       -14.0         0          0
# 88                ...                       -18.0         0          0
# 114               ...                       -11.0         0          0
# 126               ...                        17.0         0          0
# 127               ...                        -8.0         0          0
# 128               ...                         NaN         0          1
# 147               ...                         NaN         0          1
# 155               ...                        -2.0         0          0
# 166               ...                         NaN         0          1
# 184               ...                       -26.0         0          0
# 185               ...                       -25.0         0          0
# 186               ...                        22.0         0          0
# 187               ...                        -6.0         0          0
# 297               ...                         NaN         0          1
# 306               ...                         NaN         0          1
# 707               ...                       -16.0         0          0
# 846               ...                         2.0         0          0
# 847               ...                        -6.0         0          0
# 985               ...                       -12.0         0          0
# 1246              ...                       -38.0         0          0
#
#       CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 0                     NaN               NaN             NaN            NaN
# 1                     NaN               NaN             NaN            NaN
# 2                     NaN               NaN             NaN            NaN
# 3                     NaN               NaN             NaN            NaN
# 4                     NaN               NaN             NaN            NaN
# 5                     NaN               NaN             NaN            NaN
# 6                     NaN               NaN             NaN            NaN
# 7                     NaN               NaN             NaN            NaN
# 8                     NaN               NaN             NaN            NaN
# 9                     NaN               NaN             NaN            NaN
# 10                    NaN               NaN             NaN            NaN
# 11                    NaN               NaN             NaN            NaN
# 12                    NaN               NaN             NaN            NaN
# 13                    NaN               NaN             NaN            NaN
# 15                    NaN               NaN             NaN            NaN
# 17                    NaN               NaN             NaN            NaN
# 18                    NaN               NaN             NaN            NaN
# 20                    NaN               NaN             NaN            NaN
# 21                    NaN               NaN             NaN            NaN
# 22                    NaN               NaN             NaN            NaN
# 25                    NaN               NaN             NaN            NaN
# 26                    NaN               NaN             NaN            NaN
# 27                    NaN              25.0             0.0            0.0
# 28                    NaN               NaN             NaN            NaN
# 30                    NaN              43.0             0.0            0.0
# 35                    NaN               0.0             0.0           15.0
# 36                    NaN               NaN             NaN            NaN
# 37                    NaN               NaN             NaN            NaN
# 39                    NaN               NaN             NaN            NaN
# 45                    NaN               NaN             NaN            NaN
# ...                   ...               ...             ...            ...
# 66                    NaN               NaN             NaN            NaN
# 67                    NaN               NaN             NaN            NaN
# 68                      B               NaN             NaN            NaN
# 72                    NaN               NaN             NaN            NaN
# 76                    NaN               NaN             NaN            NaN
# 77                    NaN               NaN             NaN            NaN
# 78                    NaN               NaN             NaN            NaN
# 80                    NaN               NaN             NaN            NaN
# 81                    NaN               NaN             NaN            NaN
# 82                      B               NaN             NaN            NaN
# 87                    NaN               NaN             NaN            NaN
# 88                    NaN               NaN             NaN            NaN
# 114                   NaN               NaN             NaN            NaN
# 126                   NaN               0.0             0.0           17.0
# 127                   NaN               NaN             NaN            NaN
# 128                     B               NaN             NaN            NaN
# 147                     B               NaN             NaN            NaN
# 155                   NaN               NaN             NaN            NaN
# 166                     B               NaN             NaN            NaN
# 184                   NaN               NaN             NaN            NaN
# 185                   NaN               NaN             NaN            NaN
# 186                   NaN              15.0             0.0            7.0
# 187                   NaN               NaN             NaN            NaN
# 297                     A               NaN             NaN            NaN
# 306                     B               NaN             NaN            NaN
# 707                   NaN               NaN             NaN            NaN
# 846                   NaN               NaN             NaN            NaN
# 847                   NaN               NaN             NaN            NaN
# 985                   NaN               NaN             NaN            NaN
# 1246                  NaN               NaN             NaN            NaN
#
#       LATE_AIRCRAFT_DELAY  WEATHER_DELAY                       AIRLINE
# 0                     NaN            NaN          Alaska Airlines Inc.
# 1                     NaN            NaN        American Airlines Inc.
# 2                     NaN            NaN               US Airways Inc.
# 3                     NaN            NaN        American Airlines Inc.
# 4                     NaN            NaN          Alaska Airlines Inc.
# 5                     NaN            NaN          Delta Air Lines Inc.
# 6                     NaN            NaN              Spirit Air Lines
# 7                     NaN            NaN               US Airways Inc.
# 8                     NaN            NaN        American Airlines Inc.
# 9                     NaN            NaN          Delta Air Lines Inc.
# 10                    NaN            NaN          Delta Air Lines Inc.
# 11                    NaN            NaN        American Airlines Inc.
# 12                    NaN            NaN          Delta Air Lines Inc.
# 13                    NaN            NaN          Delta Air Lines Inc.
# 15                    NaN            NaN          Alaska Airlines Inc.
# 17                    NaN            NaN         United Air Lines Inc.
# 18                    NaN            NaN          Alaska Airlines Inc.
# 20                    NaN            NaN              Spirit Air Lines
# 21                    NaN            NaN        American Airlines Inc.
# 22                    NaN            NaN              Spirit Air Lines
# 25                    NaN            NaN         United Air Lines Inc.
# 26                    NaN            NaN          Alaska Airlines Inc.
# 27                    0.0            0.0              Spirit Air Lines
# 28                    NaN            NaN               US Airways Inc.
# 30                    0.0            0.0              Spirit Air Lines
# 35                    0.0            0.0        Hawaiian Airlines Inc.
# 36                    NaN            NaN               US Airways Inc.
# 37                    NaN            NaN         United Air Lines Inc.
# 39                    NaN            NaN               JetBlue Airways
# 45                    NaN            NaN               JetBlue Airways
# ...                   ...            ...                           ...
# 66                    NaN            NaN         Skywest Airlines Inc.
# 67                    NaN            NaN         Skywest Airlines Inc.
# 68                    NaN            NaN         Skywest Airlines Inc.
# 72                    NaN            NaN   Atlantic Southeast Airlines
# 76                    NaN            NaN   Atlantic Southeast Airlines
# 77                    NaN            NaN   Atlantic Southeast Airlines
# 78                    NaN            NaN         Skywest Airlines Inc.
# 80                    NaN            NaN        Hawaiian Airlines Inc.
# 81                    NaN            NaN   Atlantic Southeast Airlines
# 82                    NaN            NaN  American Eagle Airlines Inc.
# 87                    NaN            NaN   Atlantic Southeast Airlines
# 88                    NaN            NaN        Frontier Airlines Inc.
# 114                   NaN            NaN        Frontier Airlines Inc.
# 126                   0.0            0.0        Frontier Airlines Inc.
# 127                   NaN            NaN        Frontier Airlines Inc.
# 128                   NaN            NaN  American Eagle Airlines Inc.
# 147                   NaN            NaN  American Eagle Airlines Inc.
# 155                   NaN            NaN        Southwest Airlines Co.
# 166                   NaN            NaN  American Eagle Airlines Inc.
# 184                   NaN            NaN        Southwest Airlines Co.
# 185                   NaN            NaN        Southwest Airlines Co.
# 186                   0.0            0.0        Southwest Airlines Co.
# 187                   NaN            NaN        Southwest Airlines Co.
# 297                   NaN            NaN        Frontier Airlines Inc.
# 306                   NaN            NaN  American Eagle Airlines Inc.
# 707                   NaN            NaN                Virgin America
# 846                   NaN            NaN                Virgin America
# 847                   NaN            NaN                Virgin America
# 985                   NaN            NaN                Virgin America
# 1246                  NaN            NaN                Virgin America
#
# [70 rows x 32 columns]

# %%
flights_with_airlines.groupby(['AIRLINE'])['FLIGHT_NUMBER'].head()
# Out:
# 0         98
# 1       2336
# 2        840
# 3        258
# 4        135
# 5        806
# 6        612
# 7       2013
# 8       1112
# 9       1173
# 10      2336
# 11      1674
# 12      1434
# 13      2324
# 15       108
# 17      1197
# 18       122
# 20       520
# 21       371
# 22       214
# 25      1545
# 26       130
# 27       597
# 28       413
# 30       168
# 35        17
# 36       617
# 37      1528
# 39       304
# 45      1990
#         ...
# 66      7404
# 67      7419
# 68      5254
# 72      4354
# 76      4685
# 77      5583
# 78      5484
# 80       103
# 81      5187
# 82      2859
# 87      5764
# 88      1279
# 114      161
# 126      365
# 127      117
# 128     2926
# 147     3534
# 155      526
# 166     3161
# 184     4122
# 185     4822
# 186     2215
# 187      676
# 297      865
# 306     2898
# 707      922
# 846      399
# 847      897
# 985       12
# 1246     404
# Name: FLIGHT_NUMBER, dtype: int64

# %%
flights_with_airlines.groupby(['AIRLINE'])['FLIGHT_NUMBER'].count()
# Out:
# AIRLINE
# Alaska Airlines Inc.             172521
# American Airlines Inc.           725984
# American Eagle Airlines Inc.     294632
# Atlantic Southeast Airlines      571977
# Delta Air Lines Inc.             875881
# Frontier Airlines Inc.            90836
# Hawaiian Airlines Inc.            76272
# JetBlue Airways                  267048
# Skywest Airlines Inc.            588353
# Southwest Airlines Co.          1261855
# Spirit Air Lines                 117379
# US Airways Inc.                  198715
# United Air Lines Inc.            515723
# Virgin America                    61903
# Name: FLIGHT_NUMBER, dtype: int64

# %%
flights_with_airlines.groupby(['AIRLINE'])['FLIGHT_NUMBER'].sum()
# Out:
# AIRLINE
# Alaska Airlines Inc.              73650485
# American Airlines Inc.           930458522
# American Eagle Airlines Inc.     976164658
# Atlantic Southeast Airlines     2692126057
# Delta Air Lines Inc.            1415689021
# Frontier Airlines Inc.            74499475
# Hawaiian Airlines Inc.            16587390
# JetBlue Airways                  243401193
# Skywest Airlines Inc.           3029514377
# Southwest Airlines Co.          2283711458
# Spirit Air Lines                  63558819
# US Airways Inc.                  263036318
# United Air Lines Inc.            547410018
# Virgin America                    35590551
# Name: FLIGHT_NUMBER, dtype: int64

# %%
pd.DataFrame({'FLIGHT_COUNT' : flights_with_airlines.groupby(['AIRLINE'])['FLIGHT_NUMBER'].count()})
# Out:
#                               FLIGHT_COUNT
# AIRLINE
# Alaska Airlines Inc.                172521
# American Airlines Inc.              725984
# American Eagle Airlines Inc.        294632
# Atlantic Southeast Airlines         571977
# Delta Air Lines Inc.                875881
# Frontier Airlines Inc.               90836
# Hawaiian Airlines Inc.               76272
# JetBlue Airways                     267048
# Skywest Airlines Inc.               588353
# Southwest Airlines Co.             1261855
# Spirit Air Lines                    117379
# US Airways Inc.                     198715
# United Air Lines Inc.               515723
# Virgin America                       61903

# %%
airline_flight_count = pd.DataFrame({'FLIGHT_COUNT' : flights_with_airlines.groupby(['AIRLINE'])['FLIGHT_NUMBER'].count()}).reset_index()

# %%
airline_flight_count
# Out:
#                          AIRLINE  FLIGHT_COUNT
# 0           Alaska Airlines Inc.        172521
# 1         American Airlines Inc.        725984
# 2   American Eagle Airlines Inc.        294632
# 3    Atlantic Southeast Airlines        571977
# 4           Delta Air Lines Inc.        875881
# 5         Frontier Airlines Inc.         90836
# 6         Hawaiian Airlines Inc.         76272
# 7                JetBlue Airways        267048
# 8          Skywest Airlines Inc.        588353
# 9         Southwest Airlines Co.       1261855
# 10              Spirit Air Lines        117379
# 11               US Airways Inc.        198715
# 12         United Air Lines Inc.        515723
# 13                Virgin America         61903

# %%
airline_flight_count.sort_values(by='FLIGHT_COUNT', ascending=True)
# Out:
#                          AIRLINE  FLIGHT_COUNT
# 13                Virgin America         61903
# 6         Hawaiian Airlines Inc.         76272
# 5         Frontier Airlines Inc.         90836
# 10              Spirit Air Lines        117379
# 0           Alaska Airlines Inc.        172521
# 11               US Airways Inc.        198715
# 7                JetBlue Airways        267048
# 2   American Eagle Airlines Inc.        294632
# 12         United Air Lines Inc.        515723
# 3    Atlantic Southeast Airlines        571977
# 8          Skywest Airlines Inc.        588353
# 1         American Airlines Inc.        725984
# 4           Delta Air Lines Inc.        875881
# 9         Southwest Airlines Co.       1261855

# %% [markdown]
# ### Cantidad total de vuelos

# %%
airline_flight_total_count = airline_flight_count['FLIGHT_COUNT'].sum()
airline_flight_total_count
# Out:
# 5819079

# %% [markdown]
# ### Calculando el Porcentaje de Vuelos

# %%
airline_flight_count['AIRLINE_FLIGHT_PERCENTAGE'] = airline_flight_count['FLIGHT_COUNT'] / airline_flight_total_count

# %%
airline_flight_count
# Out:
#                          AIRLINE  FLIGHT_COUNT  AIRLINE_FLIGHT_PERCENTAGE
# 0           Alaska Airlines Inc.        172521                   0.029647
# 1         American Airlines Inc.        725984                   0.124759
# 2   American Eagle Airlines Inc.        294632                   0.050632
# 3    Atlantic Southeast Airlines        571977                   0.098293
# 4           Delta Air Lines Inc.        875881                   0.150519
# 5         Frontier Airlines Inc.         90836                   0.015610
# 6         Hawaiian Airlines Inc.         76272                   0.013107
# 7                JetBlue Airways        267048                   0.045892
# 8          Skywest Airlines Inc.        588353                   0.101108
# 9         Southwest Airlines Co.       1261855                   0.216848
# 10              Spirit Air Lines        117379                   0.020171
# 11               US Airways Inc.        198715                   0.034149
# 12         United Air Lines Inc.        515723                   0.088626
# 13                Virgin America         61903                   0.010638

# %% [markdown]
# Podemos realizar tambien algunas verificaciones, como que los porcentajes cierren, etc.

# %%
plt.figure()
#comparar porcentaje y totales
airline_flight_count.set_index(['AIRLINE'])['AIRLINE_FLIGHT_PERCENTAGE'].plot.pie(figsize=(8, 8),autopct='%.2f')

# %% [markdown]
# ### Calculando Tasas de Cancelaciones por Aerolinea

# %%
airline_cancellation_rate = pd.DataFrame({'CANCELLATION_RATE' : flights_with_airlines.groupby(['AIRLINE'])['CANCELLED'].mean()}).reset_index()

# %%
airline_cancellation_rate
# Out:
#                          AIRLINE  CANCELLATION_RATE
# 0           Alaska Airlines Inc.           0.003878
# 1         American Airlines Inc.           0.015040
# 2   American Eagle Airlines Inc.           0.050996
# 3    Atlantic Southeast Airlines           0.026629
# 4           Delta Air Lines Inc.           0.004366
# 5         Frontier Airlines Inc.           0.006473
# 6         Hawaiian Airlines Inc.           0.002242
# 7                JetBlue Airways           0.016012
# 8          Skywest Airlines Inc.           0.016929
# 9         Southwest Airlines Co.           0.012714
# 10              Spirit Air Lines           0.017073
# 11               US Airways Inc.           0.020466
# 12         United Air Lines Inc.           0.012745
# 13                Virgin America           0.008626

# %%
airline_divertion_rate = pd.DataFrame({'DIVERTION_RATE' : flights_with_airlines.groupby(['AIRLINE'])['DIVERTED'].mean()}).reset_index()
airline_divertion_rate
# Out:
#                          AIRLINE  DIVERTION_RATE
# 0           Alaska Airlines Inc.        0.002394
# 1         American Airlines Inc.        0.002934
# 2   American Eagle Airlines Inc.        0.002770
# 3    Atlantic Southeast Airlines        0.003486
# 4           Delta Air Lines Inc.        0.002035
# 5         Frontier Airlines Inc.        0.001739
# 6         Hawaiian Airlines Inc.        0.000787
# 7                JetBlue Airways        0.002734
# 8          Skywest Airlines Inc.        0.002684
# 9         Southwest Airlines Co.        0.002702
# 10              Spirit Air Lines        0.001551
# 11               US Airways Inc.        0.002139
# 12         United Air Lines Inc.        0.002691
# 13                Virgin America        0.001955

# %% [markdown]
# ### Juntando la Informacion en un mismo Data Frame

# %%
# left join
airline_ranking = pd.merge(airline_flight_count, airline_cancellation_rate, left_on='AIRLINE', right_on='AIRLINE', how='left')
airline_ranking
# Out:
#                          AIRLINE  FLIGHT_COUNT  AIRLINE_FLIGHT_PERCENTAGE  \
# 0           Alaska Airlines Inc.        172521                   0.029647
# 1         American Airlines Inc.        725984                   0.124759
# 2   American Eagle Airlines Inc.        294632                   0.050632
# 3    Atlantic Southeast Airlines        571977                   0.098293
# 4           Delta Air Lines Inc.        875881                   0.150519
# 5         Frontier Airlines Inc.         90836                   0.015610
# 6         Hawaiian Airlines Inc.         76272                   0.013107
# 7                JetBlue Airways        267048                   0.045892
# 8          Skywest Airlines Inc.        588353                   0.101108
# 9         Southwest Airlines Co.       1261855                   0.216848
# 10              Spirit Air Lines        117379                   0.020171
# 11               US Airways Inc.        198715                   0.034149
# 12         United Air Lines Inc.        515723                   0.088626
# 13                Virgin America         61903                   0.010638
#
#     CANCELLATION_RATE
# 0            0.003878
# 1            0.015040
# 2            0.050996
# 3            0.026629
# 4            0.004366
# 5            0.006473
# 6            0.002242
# 7            0.016012
# 8            0.016929
# 9            0.012714
# 10           0.017073
# 11           0.020466
# 12           0.012745
# 13           0.008626

# %%
# left join
airline_ranking = pd.merge(airline_ranking, airline_divertion_rate, left_on='AIRLINE', right_on='AIRLINE', how='left')
airline_ranking
# Out:
#                          AIRLINE  FLIGHT_COUNT  AIRLINE_FLIGHT_PERCENTAGE  \
# 0           Alaska Airlines Inc.        172521                   0.029647
# 1         American Airlines Inc.        725984                   0.124759
# 2   American Eagle Airlines Inc.        294632                   0.050632
# 3    Atlantic Southeast Airlines        571977                   0.098293
# 4           Delta Air Lines Inc.        875881                   0.150519
# 5         Frontier Airlines Inc.         90836                   0.015610
# 6         Hawaiian Airlines Inc.         76272                   0.013107
# 7                JetBlue Airways        267048                   0.045892
# 8          Skywest Airlines Inc.        588353                   0.101108
# 9         Southwest Airlines Co.       1261855                   0.216848
# 10              Spirit Air Lines        117379                   0.020171
# 11               US Airways Inc.        198715                   0.034149
# 12         United Air Lines Inc.        515723                   0.088626
# 13                Virgin America         61903                   0.010638
#
#     CANCELLATION_RATE  DIVERTION_RATE
# 0            0.003878        0.002394
# 1            0.015040        0.002934
# 2            0.050996        0.002770
# 3            0.026629        0.003486
# 4            0.004366        0.002035
# 5            0.006473        0.001739
# 6            0.002242        0.000787
# 7            0.016012        0.002734
# 8            0.016929        0.002684
# 9            0.012714        0.002702
# 10           0.017073        0.001551
# 11           0.020466        0.002139
# 12           0.012745        0.002691
# 13           0.008626        0.001955

# %% [markdown]
# ### Visualizando el Ranking

# %%
airline_ranking_sorted = airline_ranking.sort_values(by='FLIGHT_COUNT',ascending=False)

# %%
airline_ranking_sorted
# Out:
#                          AIRLINE  FLIGHT_COUNT  AIRLINE_FLIGHT_PERCENTAGE  \
# 9         Southwest Airlines Co.       1261855                   0.216848
# 4           Delta Air Lines Inc.        875881                   0.150519
# 1         American Airlines Inc.        725984                   0.124759
# 8          Skywest Airlines Inc.        588353                   0.101108
# 3    Atlantic Southeast Airlines        571977                   0.098293
# 12         United Air Lines Inc.        515723                   0.088626
# 2   American Eagle Airlines Inc.        294632                   0.050632
# 7                JetBlue Airways        267048                   0.045892
# 11               US Airways Inc.        198715                   0.034149
# 0           Alaska Airlines Inc.        172521                   0.029647
# 10              Spirit Air Lines        117379                   0.020171
# 5         Frontier Airlines Inc.         90836                   0.015610
# 6         Hawaiian Airlines Inc.         76272                   0.013107
# 13                Virgin America         61903                   0.010638
#
#     CANCELLATION_RATE  DIVERTION_RATE
# 9            0.012714        0.002702
# 4            0.004366        0.002035
# 1            0.015040        0.002934
# 8            0.016929        0.002684
# 3            0.026629        0.003486
# 12           0.012745        0.002691
# 2            0.050996        0.002770
# 7            0.016012        0.002734
# 11           0.020466        0.002139
# 0            0.003878        0.002394
# 10           0.017073        0.001551
# 5            0.006473        0.001739
# 6            0.002242        0.000787
# 13           0.008626        0.001955

# %%
airline_ranking_sorted.reset_index()
# Out:
#     index                       AIRLINE  FLIGHT_COUNT  \
# 0       9        Southwest Airlines Co.       1261855
# 1       4          Delta Air Lines Inc.        875881
# 2       1        American Airlines Inc.        725984
# 3       8         Skywest Airlines Inc.        588353
# 4       3   Atlantic Southeast Airlines        571977
# 5      12         United Air Lines Inc.        515723
# 6       2  American Eagle Airlines Inc.        294632
# 7       7               JetBlue Airways        267048
# 8      11               US Airways Inc.        198715
# 9       0          Alaska Airlines Inc.        172521
# 10     10              Spirit Air Lines        117379
# 11      5        Frontier Airlines Inc.         90836
# 12      6        Hawaiian Airlines Inc.         76272
# 13     13                Virgin America         61903
#
#     AIRLINE_FLIGHT_PERCENTAGE  CANCELLATION_RATE  DIVERTION_RATE
# 0                    0.216848           0.012714        0.002702
# 1                    0.150519           0.004366        0.002035
# 2                    0.124759           0.015040        0.002934
# 3                    0.101108           0.016929        0.002684
# 4                    0.098293           0.026629        0.003486
# 5                    0.088626           0.012745        0.002691
# 6                    0.050632           0.050996        0.002770
# 7                    0.045892           0.016012        0.002734
# 2015-12-10    16259
# 2015-12-11    16263
# 2015-12-12    12239
# 2015-12-13    15116
# 2015-12-14    16056
# 2015-12-15    15670
# 2015-12-16    16100
# 2015-12-17    16579
# 2015-12-18    16710
# 2015-12-19    14724
# 2015-12-20    15865
# 2015-12-21    16306
# 2015-12-22    16261
# 2015-12-23    16481
# 2015-12-24    13338
# 2015-12-25    12633
# 2015-12-26    15273
# 2015-12-27    16509
# 2015-12-28    16312
# 2015-12-29    16199
# 2015-12-30    16260
# 2015-12-31    13133
# Name: SCHEDULED_DEPARTURE, dtype: int64

# %%
# %matplotlib inline

fig = plt.figure(figsize=(10,4));

ax = fig.add_axes([0,0,1,1]);

flights_with_airlines.groupby('DATE').count()['SCHEDULED_DEPARTURE'].plot.line(c='b', label="scheduled");
flights_with_airlines[flights_with_airlines['CANCELLED'] == 0].groupby('DATE').count()['SCHEDULED_DEPARTURE'].plot.line(c='g', label="operated");
flights_with_airlines[flights_with_airlines['CANCELLED'] == 1].groupby('DATE').count()['SCHEDULED_DEPARTURE'].plot.line(c='r', label="cancelled");

ax.legend();

# %% [markdown]
# ### Apendice: Modificando los datos en data frame (map, apply)

# %%
airline_ranking_sorted.reset_index()['AIRLINE_FLIGHT_PERCENTAGE'].map(lambda x: x * 100)
# Out:
# 0     21.684789
# 1     15.051884
# 2     12.475926
# 3     10.110758
# 4      9.829339
# 5      8.862622
# 6      5.063207
# 7      4.589180
# 8      3.414887
# 9      2.964748
# 10     2.017141
# 11     1.561003
# 12     1.310723
# 13     1.063794
# Name: AIRLINE_FLIGHT_PERCENTAGE, dtype: float64

# %%
# pandas.Series.map
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html

airline_ranking_sorted['AIRLINE_FLIGHT_PERCENTAGE'].map(lambda x: x * 100)
# Out:
# 9     21.684789
# 4     15.051884
# 1     12.475926
# 8     10.110758
# 3      9.829339
# 12     8.862622
# 2      5.063207
# 7      4.589180
# 11     3.414887
# 0      2.964748
# 10     2.017141
# 5      1.561003
# 6      1.310723
# 13     1.063794
# Name: AIRLINE_FLIGHT_PERCENTAGE, dtype: float64

# %%
## pandas.DataFrame.applymap
# hace sentido en dataframes a los que les podamos aplicar la funcion a cada elemento
# hace el mismo resultado que aplicar map por columna

am_df = pd.DataFrame(np.random.randn(3, 3))
am_df
# Out:
#           0         1         2
# 0  1.009891 -0.237765  1.006037
# 1 -1.017780  1.162040 -1.271409
# 2 -0.591095  0.949048  0.403087

# %%
am_df.applymap(lambda x: '%.2f' % x)
# Out:
#        0      1      2
# 0   1.01  -0.24   1.01
# 1  -1.02   1.16  -1.27
# 2  -0.59   0.95   0.40

# %%
## pandas.DataFrame.apply
# 

def normalize(col):
  mu = col.mean()
  return col.map(lambda x:x-mu)

a_df = pd.DataFrame(np.random.randn(3, 3))
a_df
# Out:
#           0         1         2
# 0  1.094864 -0.069499 -0.860208
# 1  0.202747  0.800192  2.010591
# 2  0.672679  0.479871 -1.981821

# %%
a_df.apply(normalize)
# Out:
#           0        1         2
# 0  0.438101 -0.47302 -0.583062
# 1 -0.454017  0.39667  2.287737
# 2  0.015915  0.07635 -1.704675
